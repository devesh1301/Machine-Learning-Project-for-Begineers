# %% [markdown]
# # Import important libraries

# %%
import pandas as pd
import numpy as np
import re
import string

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize, sent_tokenize

# %% [markdown]
# # Load the data

# %%
df = pd.read_csv("Data/zenrays.csv")

# %% [markdown]
# # Data preparation

# %%
df.head()
# Out:
#             Courses                                    Course_Contents
# 0  AI & ML Training  Why we require AI and ML? Problem with traditi...
# 1  Machine Learning  Introduction to Big Data and Machine Learning ...
# 2         Angular 2  Introduction to Single page application Develo...
# 3  ReactJS Training  Introduction to ES2015 (ES6) Webpack / Babel /...
# 4        Mean Stack  Introduction to Single page application Develo...

# %%
df.shape
# Out:
# (23, 2)

# %%
# A list of contractions from http://stackoverflow.com/questions/19790188/expanding-english-language-contractions-in-python
contractions = { 
"ain't": "am not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he's": "he is",
"how'd": "how did",
"how'll": "how will",
"how's": "how is",
"i'd": "i would",
"i'll": "i will",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it would",
"it'll": "it will",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"must've": "must have",
"mustn't": "must not",
"needn't": "need not",
"oughtn't": "ought not",
"shan't": "shall not",
"sha'n't": "shall not",
"she'd": "she would",
"she'll": "she will",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"that'd": "that would",
"that's": "that is",
"there'd": "there had",
"there's": "there is",
"they'd": "they would",
"they'll": "they will",
"they're": "they are",
"they've": "they have",
"wasn't": "was not",
"we'd": "we would",
"we'll": "we will",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"where'd": "where did",
"where's": "where is",
"who'll": "who will",
"who's": "who is",
"won't": "will not",
"wouldn't": "would not",
"you'd": "you would",
"you'll": "you will",
"you're": "you are"
}

# %%
def clean_text(text, remove_stopwords = True, lemmatization = True):
    
    # Convert words to lower case
    text = text.lower()
    lemmatizer = WordNetLemmatizer()
    #w_tokenizer = word_tokenize()
    
    # Replace contractions with their longer forms 
    if True:
        text = text.split()
        new_text = []
        for word in text:
            if word in contractions:
                new_text.append(contractions[word])
            else:
                new_text.append(word)
        text = " ".join(new_text)
    
    # Format words and remove unwanted characters
    text = re.sub(r'https?:\/\/.*[\r\n]*', ' ', text,  
                  flags=re.MULTILINE)
    text = re.sub(r'\<a href', ' ', text)
    text = re.sub(r'&amp;', ' ', text) 
    text = re.sub(r'[_"\--;%()|+&=*%.,!?:#$@\[\]/<>]', ' ', text)
    text = re.sub(r'<br />', ' ', text)
    text = re.sub(r'\'', ' ', text)
    text = re.sub(r'\d+\S\d+\S\d+', ' ', text)
    text = re.sub(r'\d+', ' ', text)
    text = re.sub(r'\[[0-9]*\]',' ',text)
#     text = re.sub(r'\s+',' ',text)
    text = re.sub(r"\b[a-z]\b", " ", text)
    
    # Optionally, remove stop words
    if remove_stopwords:
        text = text.split()
        stops = set(stopwords.words("english") + list(string.punctuation))
        text = [w for w in text if not w in stops]
        text = " ".join(text)
    
    if lemmatization:
        text = [lemmatizer.lemmatize(w) for w in word_tokenize(text)]
        text = " ".join(text)

    return text

# %%
clean_course_content = []
for s in df.Course_Contents:
    #print(msg)
    clean_course_content.append(clean_text(s, remove_stopwords=True, lemmatization=True))
print("Phrase cleaning complete.")
# Out:
# Phrase cleaning complete.

# %%
clean_course_content
# Out:
# ['require ai ml problem traditional software system opportunity ai ml need excel logical mind tool software efficiently build ml model python tensorflow popular understand actually ml model handle data preprocessing data type ml model supervised unsupervised peek reinforcement learning break data training test cross validation technique understand linear regression gradient descent actual hand understand calculation behind gradient descent brush differentiation understand math behind hand code python learn improve model overfitting one difficult aspect learn building ml model use linear regression model understand overfitting learn hand avoid overfitting bias variance tradeoff regularization ridge lasso anova test logistic regression understand classification logistic regression maximum likelihood estimation build end end model logistic regression using scikit learn hand actually build model industry code interview data science competition probability based model decision tree model understand concept entropy gini impurity information gain detailed hand project predict possible loan defaulter large multi national bank apply concept overfitting improve decision tree model without overfitting bagging boosting random forest adaboost gradient boost understand distance based model knn choose value project work predicting breast cancer power svm model can not svm popular industry learn kernel function different kernel function build ocr optical character reader help svm kernel function neural network neural network actually solve complex pattern build neural network architecture neural network mimic cognitive capability human build xor xnor logic gate neural network understand forward backward propagation plot neural network code map understanding theory practical change architecture code see neural network behaves different activation function vanishing gradient problem loss function optimization method gradient descent momentum rmsprop adam learning rate decay xavier initialization introduction kera tensorflow tf deep learning kera tensorflow backend project work basic concept clustering mean clustering hierarchical clustering build hand project social medium analysis clustering principal component analysis pca learn math behind pca learn code plot pca recommendation engine understand netflix tech giant us recommendation engine content collaborative filtering pro con different approach recommendation engine market basket analysis apriori rule build recommender system image detection image classification localization introduction convolutional neural network cnn build handwritten digit recognizer cnn stride padding concept convolutional padding fully connected layer sliding window edge detection yolo algorithm look introduction classical network like lenet iou build image classifier cnn data augmentation technique natural language processing nlp introduction natural language processing nlp text preprocessing lemmatization stemming syntactical parsing entity parsing ctopic modelling latent dirichlet allocation lda collapsed gibbs sampling word embedding word vec cbow skipgram model restricted boltzman machine recurrent neural network rnn long short term memory lstm build chatbot concept nlp neural network history ai state art ai type agent type environment asymptotic notation uninformed search breadth first search uniform cost search depth first search depth limited search iterative deepening depth first search bidirectional search informed search greedy best first search search beyond local search hill climbing simulated annealing beam search genetic algorithm online search informed search min max tree alpha beta pruning move ordering stochastic game constraint satisfaction problem map coloring sudoku job scheduling constraint propagation backtracking passive reinforcement learning active reinforcement learning policy search mock interview mock interview mock interview mock interview',
#  'introduction big data machine learning understanding python type learning advice applying machine learning machine learning system design basic statistic data cleaning data exploration statistical inference pgm probabilistic graphical model regression simple linear regression multiple linear regression assessing performance ridge regression feature selection lasso nearest neighbour kernel regression classification decision tree cart support vector machine svm naive bayes project work cancer detection fraud analysis spam filter creation clustering overview type clustering type clustering algorithm mean clustering hierarchical clustering difference mean hierarchical clustering application clustering project work social medium analysis clustering recommender system overview phase recommendation process recommendation filtering technique evaluation metric recommendation algorithm spark core spark architecture working rdds machine learning spark – mllib perceptron learning procedure back propagation learning procedure learning feature vector word object recognition neural net optimization make learning go faster recurrent neural network recurrent neural network way make neural network generalize better combining multiple neural network improve generalization hopfield net boltzmann machine restricted boltzmann machine rbms stacking rbms make deep belief net deep learning convolutional neural network cnn object detetcion object classification localization edge detection stride padding yolo algorithm mock interview mock interview mock interview mock interview',
#  'introduction single page application development angular opinionated angular v react v vuejs v ember angular framework v react library typescript introduction npm angular npm ecosystem evaluation quiz installing angular cli package json building app using npm package json introduction angular module understanding base module application initializer module help create modular decoupled application understanding angular component create basic component display view component help create organized application using custom tag using root component initialize application evaluation quiz angular bootstrapping angular cli directory structure angular cli json file main t main application file creating multiple module working module file understanding production dev environment scope inheritance controller using conditional statement ngif using template modifier directive looping data using ngfor understanding data binding working different data binding interpolation create component using cli regular code using import angular file using decorator angular component decorator using template html using cs file component constructor component ngoninit initialization evaulation quiz creating component inside module passing data component using input attaching event template working ngmodel passing data outside component using event emitter component hook different component hook use component lifecycle understanding component created attached destroyed inter component communication component talk using pipe angular inbuilt pipe angular working currency pipe working date pipe lower upper case pipe json pipe debugging creating custom pipe cli pipe decorator using transform function transform response creating custom pipe multiple argument evaluation quiz introduction service service singleton understanding dependency injection angular service way organize logic data service creating service using cli custom code working injectable decorator organizing service project code working inbuilt directive introduction custom directive api creating custom directive cli directive decorator creating custom directive code create directive modify html view elementref api renderer api creating event custom directive using hostlistener evaluation quiz working ngmodel template variable angular using template var v ngmodel creating form working form event collecting handling form data form validation reactive form v template form introduction reactive form creating form control code using using formgroup formcontrol formbuilder api creating dynamic control using formsgroup formscontrola form validation using validator function validators abstractcontrol validatorfn form validation using directive better approach handling event form evaluation quiz understanding observables subscriber introduction rxjs library map function introduction rest service using get post put delete need rest service v traditional ajax approach difference httpmodule v httpclient using http module connect server getting data sending custom header angular frontend using header class requestoptions class angular creating rest app using http module crud operation using httpclient talk server create entire rest app using httpclient module using interceptor securing server communication evaluation quiz introduction unit testing setting unit testing using karma creating unit test component creating unit test service evaluation quiz authentication using jwt securing angular application protecting attack deploying angular application working dist folder aot compilation optimizing angular app production mock interview mock interview mock interview mock interview',
#  'introduction e e webpack babel npm project structure first react app e introduction role react problem react address react development environment node npm webpack babel babel presets jsx react component virtual dom change detection one way data binding component without state class v function react component element instance jsx react createelement component lifecycle using prop data passing internal state class component ref input handling creating react app passing prop initializing state updating state parent child component main component router route indexroute authentication handling event react router implement react router master detail web application presentational component v container component data fetching controlled component v uncontrolled component materialui data behaviour data data mutation pure function redux architecture philosophy single immutable state pure impure function integration react provider store reducer action unique source truth provider connect application using react redux fetching data server redux introducing redux middleware exercise build redux middleware thunk action dispatch action exercise implement loading indicator using thunk mock interview mock interview mock interview mock interview',
#  'introduction single page application development angular opinionated angular v react v vuejs v ember angular framework v react library introduction npm angular npm ecosystem evaluation quiz installing angular cli package json building app using npm package json introduction angular module understanding base module application initializer module help create modular decoupled application understanding angular component create basic component display view component help create organized application using custom tag using root component initialize application evaluation quiz angular bootstrapping angular cli directory structure angular cli json file main t main application file creating multiple module working module file understanding production dev environment scope inheritance controller using conditional statement ngif using template modifier directive looping data using ngfor understanding data binding working different data binding interpolation create component using cli regular code using import angular file using decorator angular component decorator using template html using cs file component constructor component ngoninit initialization evaulation quiz creating component inside module passing data component using input attaching event template working ngmodel passing data outside component using event emitter component hook different component hook use component lifecycle understanding component created attached destroyed inter component communication component talk using pipe angular inbuilt pipe angular working currency pipe working date pipe lower upper case pipe json pipe debugging creating custom pipe cli pipe decorator using transform function transform response creating custom pipe multiple argument evaluation quiz introduction service service singleton understanding dependency injection angular service way organize logic data service creating service using cli custom code working injectable decorator organizing service project code working inbuilt directive introduction custom directive api creating custom directive cli directive decorator creating custom directive code create directive modify html view elementref api renderer api creating event custom directive using hostlistener evaluation quiz working ngmodel template variable angular using template var v ngmodel creating form working form event collecting handling form data form validation reactive form v template form introduction reactive form creating form control code using using formgroup formcontrol formbuilder api creating dynamic control using formsgroup formscontrola form validation using validator function validators abstractcontrol validatorfn form validation using directive better approach handling event form evaluation quiz understanding observables subscriber introduction rxjs library map function introduction rest service using get post put delete need rest service v traditional ajax approach difference httpmodule v httpclient using http module connect server getting data sending custom header angular frontend using header class requestoptions class angular creating rest app using http module crud operation using httpclient talk server create entire rest app using httpclient module using interceptor securing server communication evaluation quiz introduction unit testing setting unit testing using karma creating unit test component creating unit test service evaluation quiz authentication using jwt securing angular application protecting attack deploying angular application working dist folder aot compilation optimizing angular app production introduction node j importance asynchronous asynchronous javascript node j event loop node j process file system f module reading directory reading file streaming building server creating server http receiving data http streaming working tcp commonjs module npm package event emitter api nodemon nodemailer socket io cryptography session handling cookie handling authentication connecting slack app introduc ...
#  'cspring framework ioc dependency injection spring container beanfactory applicationcontext xmlbeanfactory classpathxmlapplicationcontext filesystemxmlapplicationcontext spring scope singleton prototype bean life cycle setup tear init method destroy method beanpostprocessor spring bean definition inheritance dependency injection constructor setter method injecting collection inner bean bean autowiring name type constructor annotation injection required true false autowiring setter property constructor qualifier component life cycle spring wiring loose coupling jdbctemplate\\xa update queryforobject preparedstatementcreator preparedstatementsetter datasource advice returning throwing around practical session model vew controller controller command class validator formcontroller exceptionresolver viewresolver mvc annotation controller requestmapping exceptionhandler orm jdbc hibernate transition pojo db mapping hibernate config file class annotation association persistence session sessionfactory transaction spring hibernate java persistence api entity primary key persistent field entity entity inheritance entity manager managing entity jpql service oriented architecture xml soap http web service description language wsdl universal description discovery integration representational state transfer restful webservices practical session mock interview mock interview mock interview mock interview',
#  'introduction python programming language introduces python basic data type file function error handling basic python syntax reading converting user input calculating stored value running python script python script unix window python editor ide language component control flow syntax intending statement relational operator logical operator true false bite wise operator loop break continue loop collection introduction list tuples set dictionary sorting dictionary copying collection summary string formatting string operation writing list tuples function sequence function method work sequence slice stride skipping around sequence manipulating list tuples list comprehension dicts working \\xa dicts applying dicts counting word complex application word pair frequency reading writing file flat file csv file excel file \\xa json file appending file seeking arbitrary position parsing technique large file installing different inbuilt package module per project requirement pywinauto pywin pyodbc win amd py mysql python ftputil py exe standard module importing module math module random module package composition function parameter functional documentation keyword optional parameter passing collection function variable number argument scope passing function function mapping function dictionary lambda closure variable scope returning single value multiple value handling different error exception achieve hassle free automation handling multiple exception standard exception hierarchy using module raise assert writing exception class designing custom logger mechanism record automation script flow launching external program operating system related task stdio system command walking directory random number date time introduction python class defining class initializes instance method property class method data static method private method inheritance\\xa polymorphism thread process threading library module thread synchronization queue standard library multiprocessing library module environment launching command creating process directory command miscellaneous o call walking directory network programming introduction client server program evaluation client server working various secured third party apiôçös python intro relational database sql database mysql \\xa mongo db crud operation use inbuilt database module mysql alerting mail critical monitoring service python creating database project django installation required module installation creating project apps using django dev server development creating first web app django designing url writing handler view exception handling exposing http rest apis handling client http get post put update delete request processing data file providing json http creating activating model information insertion retrieval updation deletion using django object relation mapping orm exposing json data activating admin module managing user permission session handling building custom ui apps using admin module hosting client side code written using angularjs integration client side code server side django logging debugging purpose testing client apis deploying django application cloud elastic search kibana data analytics mock interview mock interview mock interview mock interview',
#  'html history timeline html design principle html html review doctype root element element content model new structural element html html comparison new element redefined element obsolete element html outline use feature detection technique feature detection example feature detection modernizr cs styling cs validating accessibility wai aria html form overview new input type contact info new input type native date picking opera rendering date input type new input type number range new attribute detecting support accessibility wai aria styling form element avoiding validation constraint validation api custom validation example audio video element using medium element attribute format serving device specific file accessibility backwards compatibility medium api rolling custom control canvas overview canvas element context coordinate system rectangle path path drawing method curve arc color style geolocation overview privacy concern api method api attribute using geolocation api success handler using geolocation api error handler using geolocation api third argument watchposition clearwatch fallback support geo j local data storage overview web storage overview web storage api data type json javascript object notation accessing storage storage event database apis web worker overview worker message passing shared worker parent page latest standard cs cs cs border radius box shadow text shadow transition transforms gradient multiple background font face introduction installing bootstrap creating first page using bootstrap bootstrap container bootstrap grid system example grid system clearfix nested column typography handling table form handling horizontal form vertical form inline form input control icon form element button form validation handling image navigation item dropdown navbars modal carousel introduction javascript basic rule dot notation square bracket notation method property implicit window object getelementbyid method event handler javascript variable loosely typed language storing user entered data array declaring using array associative array understanding controller boundary scope array property method javascript operator javascript built function number object string object isnan object parsefloat parseint comparison passing value function note variable scope returning value function comparison string object math object date object us using type operator else else condition switch case loop syntax loop syntax loop syntax loop syntax understanding dom dom tree traversing dom accessing dom element modifying dom element using javascript accessing form data object cleaner validation validating radio button validating checkboxes validating select menu focus blur change event change validating text area introduction angularjs angularjs opinionated angularjs component architecture creating boundary using ng app model view controller template data binding repeating element template using expression cs class style using controller ui responsibility separation understanding controller boundary scope scope inheritance controller responding model change working inbuilt directive filter overview understanding filter expression building custom filter implementing filter custom filter example understanding built directive understanding routing angularjs using ngroute module creating route passing parameter route creating simple commerce front end page using angularjs dependency injection service factory provider modularity using service injecting service creating custom factory provider creating example using service directive overview creating directive directive definition object compilation linking creating component implementing directive example app understanding server communicating angular communicating http installation configuration apache administration virtual host alias directory protection cgi apache module common apache module apache config file variable overwriting config value using htaccess file user webpage wam ...
#  'java oops concept need java class interface object constructor field method variable keywords inheritance method overloading overriding access specifier jar file package comparing printing object final variable initializing bitwise operation operator data type generic type date calendar inner anonymous class string string buffer \\xa array switch statement exception reflection clone assertion file handling io package class enum type multi threading concurrency data structure collection framework sorting jdbc sql database concept driver servlets webserver http method javaserver page jsp jstl java cryptography encryption java mail cryptographic protocol jms xml cspring framework ioc dependency injection spring container beanfactory applicationcontext xmlbeanfactory classpathxmlapplicationcontext filesystemxmlapplicationcontext spring scope singleton prototype bean life cycle setup tear init method destroy method beanpostprocessor spring bean definition inheritance dependency injection constructor setter method injecting collection inner bean bean autowiring name type constructor annotation injection required true false autowiring setter property constructor qualifier component life cycle spring wiring loose coupling jdbctemplate ôçô update queryforobject preparedstatementcreator preparedstatementsetter datasource advice returning throwing around practical session model vew controller controller command class validator formcontroller exceptionresolver viewresolver mvc annotation controller requestmapping exceptionhandler orm jdbc hibernate transition pojo db mapping hibernate config file class annotation association persistence session sessionfactory transaction spring hibernate java persistence api entity primary key persistent field entity entity inheritance entity manager managing entity jpql service oriented architecture xml soap http web service description language ôçô wsdl universal description discovery integration representational state transfer restful webservices mock interview mock interview mock interview mock interview',
#  'introduction javascript basic rule dot notation square bracket notation method property implicit window object getelementbyid method event handler javascript variable loosely typed language storing user entered data array declaring using array associative array array property method javascript operator javascript built function number object string object isnan object parsefloat parseint comparison passing value function note variable scope returning value function comparison string object math object date object us using type operator else else condition switch case loop syntax loop syntax loop syntax loop syntax understanding dom dom tree traversing dom accessing dom element modifying dom element using javascript accessing form data object cleaner validation validating radio button validating checkboxes validating select menu focus blur change event change validating text area understanding class creating class variable public private variable class member public v private member javascript inner function v class member using object context creating class template using javascript understanding constructor creating object using constructor object creation constructor v literal literal v constructor understanding class property creating property class accessing property outside class using object public property li private property specific use case private property understanding method function class creating method accessing method outside class public v private method using public method outside class private method use case class specific computation using private method understanding inheritance javascript implementing inheritance javascript single v multiple inheritance javascript prototypal inheritance restricting inheritance understand object javascript creating object using literal creating object using constructor function understanding creating inner function using member variable object initialization v literal understanding object context inside member function using apply using apply transfer context object context class function understanding variable declaration declaration diff type language variable hoisting function variable hoisting scenario understanding function variable javascript immediate function using immediate function clean global namespace using namespaces javascript anonymous function application assigning value function variable closure closure application closure loop scope chain getters setter iterators eval understanding prototype enumerable property iterating property understanding proto proto chain proto hierarchy browser environment proto behaviour understanding inheritance javascript inheritance using prototype inheritance using temporary constructor creating extend function inheritance creating super javascript object shallow copy object deep copy multiple inheritance parasitic inheritance mock interview mock interview mock interview mock interview',
#  'installation configuration apache administration virtual host alias directory protection cgi apache module common apache module apache config file variable overwriting config value using htaccess file user webpage wamp installation wamp component configuring apache wamp configuring php wamp mysql basic configuration upgrading downgrading version wamp hand session installing development environ php mysql apache post install configuration php ini file enabling disabling feature important tag php ini file understanding httpd conf file fine tuning apache environmental security consideration unix linux exercise project defining array php list hash use list array hash extracting array element loop catching list element separate variable using split list extracting hash element loop using value extracting hash key loop using key extraction value key using value key syntax serializing un serializing array hash storing array disk file using later passing array reference value function array function array split array chunk array count value array fill array key exists array pop array push etc merging array basic defining php class constructor default constructor desconstructor php public private protected variable including external class file function overloading inheritance example class using sample user class requireôçø ôç£includeôçø ôç£include onceôçø hand session auto loading class object using static keyword class scope resolution class constant abstract class concept demo interface concept demo object iteration pattern magic method using final keyword object cloning basic pre defined variable variable scope using global keyword globals writing user defined function many different way write php function passing argument returning value returning multiple value default parameter precaution filesystem basename copy dirname fopen fread fwrite foef fclose fgets file filesize fputs dir file executable stat string trim echo explode fprintf implode join md str word count strlen substr substr replace wordwrap http header base encode base decode parse url urlencode urldecode file upload post method uploads error message mathematical function ab sin co tan pi pow min max log log hexdec exp deg rad rad deg srand rand round nan infinite finite fmod floor ceil sqrt writing user defined function many different way write php function passing argument returning value returning multiple value default parameter precaution filesystem basename copy dirname fopen fread fwrite foef fclose fgets file filesize fputs dir file executable stat string trim echo explode fprintf implode join md str word count strlen substr substr replace wordwrap http header base encode base decode parse url urlencode urldecode file upload post method uploads error message mathematical function ab sin co tan pi pow min max log log hexdec exp deg rad rad deg srand rand round nan infinite finite fmod floor ceil sqrt understanding form input field reading form variable php using post method reading variable php using get method carrying value one page another using query string php session cooky concept database abstraction implementing db class mysql example making database query using implementing db class changing db class work sqlite understanding ajax using php ajax using javascript pas variable php using php render javascript demo login using php ajax passing variable php javascript v another approach using cooky implementing working soap client server using nusoap implementing working xml rpc client server using pear practice web service writing new working service introduction framework introduction mvc design pattern working controller view understanding templating introduction mvc design pattern introduction laravel understanding composer installing laravel understanding laravel directory structure creating starter app using laravel working database migration understanding controller laravel working controller understanding view laravel creating view class understan ...
#  'drupal began drupal drupal version difference technology drupal use drupal architecture drupal content management system content management framework web application framework module theme node block bootstrap hook callback configuring wamp drupal installing drupal admin interface creating content managing content site building site configuration user management report help core required core optional enabled core optional disabled downloading enabling drupal search working indexing cron popular module module selection evaluation job site setup block region default block custom block configuring block enabling default block controlling front page download method file module image module storing user uploaded material page article creating custom content type adding field content type text field adding field content type contributed module link field adding field content type contributed module image field adding field content type contributed module medium field adding field content type contributed module field group adding field content type contributed module node reference manage display\\xa setting teaser body display label display format taxonomy vocabulary required vocabulary controlled vocabulary term single multiple term adding term view content term storing taxonomy module based vocabulary common function overview view view type default view view type override view view type normal view view handler display basic setting job based site setup job search listing display display type feed view creation basic setting view creation field v node view creation filter view creation argument view creation relationship overview panel panel layout panel page introduction solr search installation solr integration drupal search panel view argument social networking site setup messaging instant messaging profile architecture theme system theme template info file theme engine hook theme creation file installing theme creating enabling customized subtheme theme inheritance subthemes modifying base theme theming custom stylesheet implementation hierarchy preprocess hook theme preprocessors hook overriding theme behavior php networking site custom theme view coding hook \\xa menu system permission working drupal database api creating simple hello world module form processing validation form submission redirection caching module using inbuilt cache creating basic form module template passing data template module drupal basic caching block level caching using page boost memcached introduction installation working drush deploying drupal application porting working nodeapi form alter advanced hook hr portal setup introduction drupal drupal v drupal drupal architecture drupal admin panel understanding drupal upgrade process understanding yaml file drupal configuration process drupal deployment theme customization theme development module development securing drupal site',
#  'html history timeline html design principle html html review doctype root element element content model new structural element html html comparison new element redefined element obsolete element html outline use feature detection technique feature detection example feature detection modernizr cs styling validating accessibility wai aria html form overview new input type contact info new input type native date picking opera rendering date input type new input type number range new attribute detecting support accessibility wai aria styling form element avoiding validation constraint validation api custom validation example audio video element using medium element attribute format serving device specific file accessibility backwards compatibility medium api rolling custom control canvas overview canvas element context coordinate system rectangle path path drawing method curve arc color style geolocation overview privacy concern api method api attribute using geolocation api success handler using geolocation api error handler using geolocation api third argument watchposition clearwatch fallback support geo j local data storage overview web storage overview web storage api data type json javascript object notation accessing storage storage event database apis web worker overview worker message passing shared worker parent page',
#  'jquery fundamental need jquery jquery alternative document ready handler making dom element selecting element manipulation using basic cs selector using child container attribute selector selecting position searching element jquery searching parent child element search traversing element selecting child parent element generating new html dom manipulation using jquery multiple dom manipulation function event handling jquery handling click blur submit related event event delegation introduction ajax making get request ajax making post request making rest request understanding jsonp cross domain request promise api understanding promise deferred object creating asynchronous workflow promise api handling multiple request deferred promise creating jquery plugins optimizing jquery security jquery responding model change working inbuilt directive mock interview mock interview mock interview mock interview mock interview mock interview mock interview mock interview',
#  'history difference linux window difference linux unix gnu usage career option interesting fact linux linux virus proof various linux distribution pro con mkdir touch l pwd cd chmod df du dd adduser sort passwd rm rmdir date vi editor file structure hierarchy file permission lvm overview cron rpm make boot loader lilo grub system initialization inittab rc sysinit rc volume group physical logical volume resizing lvs etc route ifconfig ping netstat modprobe rmmod insmod lsmod modinfo ssh sshd scp single user mode rescue mode ip table file sharing samba nfs mail server using sendmail web server installation apache proxy server installation using squid firewalling using iptables pam plug gable authentication module linux performance monitor sar utility monitor cpu using sar track application causing memory leak awk sed grep echo variable function lynis unix based auditing tool rootkit hunter',
#  'introduction angularjs angularjs opinionated angularjs component architecture creating boundary using ng app model view controller template data binding repeating element template using expression cs class style using controller ui responsibility separation understanding controller boundary scope scope inheritance controller responding model change working inbuilt directive filter overview understanding filter expression building custom filter implementing filter custom filter example understanding built directive understanding routing angularjs using ngroute module creating route passing parameter route creating simple commerce front end page using angularjs dependency injection service factory provider modularity using service injecting service creating custom factory provider creating example using service directive overview creating directive directive definition object compilation linking creating component implementing directive example app understanding server communicating angular communicating http configuring request sending http header caching response request response transformation working get fetch data post put delete testing model using jasmine creating unit test angularjs component using protractor end end testing creating end end test angularjs creating advanced route using ui router using local storage angularjs script optimization securing angularjs application introduction ionic framework installation configuring ionic creating apps using ionic using ionic command line deploying sample application using ionic creating simple ionic application using angularjs mock interview mock interview mock interview mock interview',
#  'web programming introduction client server architecture html javascript body document javascript event handling javascript clientside validation introduction asp net mvc first mvc web application view mvc application adding model mvc application controller actionresult type passing data view controller action selector httpget httppost built action filter understanding custom action filter user agent action filter example asynchronous controller razor introduction syntax working layout page partial view type view introducing html helper method binding html helper viewdata binding html helper model display editor helper method custom template display editor method default behaviour default model binder bind attribute introduction validating model data remote custom validation attribute custom clientside validation web configuration file custom error handling cookie cooky example understanding session login example using session working session property handling global data web application entity framework crud operation writing using business object writing using generic repository caching repository dependency injection custom controller factory url routing routing feature mvc ajax helper method bundling minification web api introduction simple web api example jquery client crud operation using webapi unit testing class unit testing controller mvc ntier layered architecture part ntier layered architecture part sample small project',
#  'software testing important waterfall model sdlc model sdlc agile model sdlc type requirement test strategy create efficient test strategy unit testing integration testing smoke testing system testing regression testing acceptance testing black box testing white box testing are\\xa test case functional test case performance test case security test case ui test case defect verification defect life cycle defect reporting tracking test summary test report preparation automation testing important learn automation limitation manual testing limitation automation testing need automate selenium kind testing perform using selenium advantage selenium difference selenium qtp ide selenium rc selenium grid selenium webdriver selenium selenium ide install selenium ide recording playback using selenium ide ide context menu action accessors assertion selenium ide verify selenium ide difference assert verify selenium ide add comment selenium ide create test case save test case selenium ide creating test suite selenium ide import test case test suite selenium ide take screenshots selenium ide limitation selenium ide important selenium ide command open click clickandwait type typekeys verifytitle asserttitle verifytextpresent verifyelementpresent verifytable waitforpagetoload waitforelementpresent goback pause captureentirepagescreenshotandwait tool identify element object firebug xpath locate element using xpath locate element using cs advantage disadvantage using xpath cs locate element id locate element name locate element link text use selenium webdriver industry difference selenium rc selenium webdriver configure selenium webdriver eclipse browser automate using selenium webdriver create script selenium webdriver automate form using selenium webdriver find broken link application using selenium webdriver automate alert using selenium webdriver automate checkbox using selenium webdriver automate dropdown using selenium webdriver automate frame using selenium webdriver give implicit explicit wait selenium webdriver capture screenshots selenium webdriver limitation selenium webdriver testng framework testng used testng make automation easy advantage using testng junit install testng eclipse annotation testng creating running simple test script using testng prioritize execution test testng hard soft assertion testng create testng xml file execute multiple test case using testng xml create test suite using testng xml advantage testng xml file perform cross browser testing using testng generating test report using testng including poi jar file project write java program read data excel sheet create property file java read data property file autoit used selenium download autoit check help section autoit use finder tool autoit create autoit script integrate autoit selenium important method used autoit maven selenium configure maven eclipse create build maven execute build maven analyze report using maven jenkins selenium download install jenkins configure jenkins create batch file execute jenkins job downloading configuring github basic git command working repository creating repository committing syncing code reverting rolling back code resolving conflict installing java installing eclipse feature java java selenium first java program data type java string class statement conditional concatenation operator loop loop practical example loop usage loop selenium creating object java local variable global variable oops concept constructor concept inheritance working example interface overloading overriding function accessing modifiers\\xa public private default protected ôçô exception handling java data driven framework keyword driven framework hybrid framework difference data driven keyword driven hybrid framework object repository selenium framework design keyword driven framework staging zenrays com website',
#  'software testing important waterfall model sdlc model sdlc agile model sdlc type requirement test strategy create efficient test strategy unit testing integration testing smoke testing system testing regression testing acceptance testing black box testing white box testing are\\xa test case functional test case performance test case security test case ui test case defect verification defect life cycle defect reporting tracking test summary test report preparation',
#  'automation testing important learn automation limitation manual testing limitation automation testing need automate selenium kind testing perform using selenium advantage selenium difference selenium qtp ide selenium rc selenium grid selenium webdriver selenium selenium ide install selenium ide recording playback using selenium ide ide context menu action accessors assertion selenium ide verify selenium ide difference assert verify selenium ide add comment selenium ide create test case save test case selenium ide creating test suite selenium ide import test case test suite selenium ide take screenshots selenium ide limitation selenium ide important selenium ide command open click clickandwait type typekeys verifytitle asserttitle verifytextpresent verifyelementpresent verifytable waitforpagetoload waitforelementpresent goback pause captureentirepagescreenshotandwait tool identify element object firebug xpath locate element using xpath locate element using cs advantage disadvantage using xpath cs locate element id locate element name locate element link text use selenium webdriver industry difference selenium rc selenium webdriver configure selenium webdriver eclipse browser automate using selenium webdriver create script selenium webdriver automate form using selenium webdriver find broken link application using selenium webdriver automate alert using selenium webdriver automate checkbox using selenium webdriver automate dropdown using selenium webdriver automate frame using selenium webdriver give implicit explicit wait selenium webdriver capture screenshots selenium webdriver limitation selenium webdriver testng framework testng used testng make automation easy advantage using testng junit install testng eclipse annotation testng creating running simple test script using testng prioritize execution test testng hard soft assertion testng create testng xml file execute multiple test case using testng xml create test suite using testng xml advantage testng xml file perform cross browser testing using testng generating test report using testng including poi jar file project write java program read data excel sheet create property file java read data property file autoit used selenium download autoit check help section autoit use finder tool autoit create autoit script integrate autoit selenium important method used autoit maven selenium configure maven eclipse create build maven execute build maven analyze report using maven jenkins selenium download install jenkins configure jenkins create batch file execute jenkins job downloading configuring github basic git command working repository creating repository committing syncing code reverting rolling back code resolving conflict installing java installing eclipse feature java java selenium first java program data type java string class statement conditional concatenation operator loop loop practical example loop usage loop selenium creating object java local variable global variable oops concept constructor concept inheritance working example interface overloading overriding function accessing modifiers\\xa public private default protected ôçô exception handling java data driven framework keyword driven framework hybrid framework difference data driven keyword driven hybrid framework object repository selenium framework design keyword driven framework staging zenrays com website',
#  'getting started using vuejs interact dom using conditionals rendering list first course project\\ —\\ athe monster slayer understanding vuejs instance moving “ real ” development workflow webpack vue cli introduction component communicating component advanced component usage second course project\\ —\\ awonderful quote handling user input form using creating directive improving app filter mixins adding animation transition connecting server via http\\ —\\ ausing vue resource routing vuejs application better state management vuex final project\\ —\\ athe stock trader deploying vuejs application course roundup',
#  'java oops concept need java class interface object constructor field method variable keywords inheritance method overloading overriding access specifier jar file javadoc api creation package comparing printing object final variable initializing bitwise operation operator data type generic type date calendar joda inner anonymous class string string buffer regular expression array switch statement exception reflection clone assertion file handling io package class enum type multi threading concurrency data structure collection framework sorting jdbc sql database concept driver socket remote communication servlets webserver http method rmi networking javaserver page jsp jstl java cryptography encryption java mail cryptographic protocol jms xml cspring framework ioc dependency injection spring container beanfactory applicationcontext xmlbeanfactory classpathxmlapplicationcontext filesystemxmlapplicationcontext spring scope singleton prototype bean life cycle setup tear init method destroy method beanpostprocessor spring bean definition inheritance dependency injection constructor setter method injecting collection inner bean bean autowiring name type constructor annotation injection required true false autowiring setter property constructor qualifier component life cycle spring wiring loose coupling jdbctemplate ôçô update queryforobject preparedstatementcreator preparedstatementsetter datasource advice returning throwing around practical session model vew controller controller command class validator formcontroller exceptionresolver viewresolver mvc annotation controller requestmapping exceptionhandler orm jdbc hibernate transition pojo db mapping hibernate config file class annotation association persistence session sessionfactory transaction spring hibernate java persistence api entity primary key persistent field entity entity inheritance entity manager managing entity jpql practical session',
#  'introduction nodejs importance asynchronous asynchronous javascript nodejs event loop nodejs process file system f module reading directory reading file streaming building server creating server http receiving data http streaming working tcp commonjs module npm package eventemitter api introduction expressjs routing configuration view middleware working data working socket io process cluster child process module cluster cluster object worker object best practice npm node j api design error handling debugging hosting node need host forever pm node window node window service iisnode unit testing mock interview mock interview mock interview mock interview']

# %%
clean_course_content1 = []
for i in clean_course_content:
    clean_course_content1.append(re.sub('(\\b[A-Za-z] \\b|\\b [A-Za-z]\\b)', '', i))

# %%
clean_course_content1
# Out:
# ['require ai ml problem traditional software system opportunity ai ml need excel logical mind tool software efficiently build ml model python tensorflow popular understand actually ml model handle data preprocessing data type ml model supervised unsupervised peek reinforcement learning break data training test cross validation technique understand linear regression gradient descent actual hand understand calculation behind gradient descent brush differentiation understand math behind hand code python learn improve model overfitting one difficult aspect learn building ml model use linear regression model understand overfitting learn hand avoid overfitting bias variance tradeoff regularization ridge lasso anova test logistic regression understand classification logistic regression maximum likelihood estimation build end end model logistic regression using scikit learn hand actually build model industry code interview data science competition probability based model decision tree model understand concept entropy gini impurity information gain detailed hand project predict possible loan defaulter large multi national bank apply concept overfitting improve decision tree model without overfitting bagging boosting random forest adaboost gradient boost understand distance based model knn choose value project work predicting breast cancer power svm model can not svm popular industry learn kernel function different kernel function build ocr optical character reader help svm kernel function neural network neural network actually solve complex pattern build neural network architecture neural network mimic cognitive capability human build xor xnor logic gate neural network understand forward backward propagation plot neural network code map understanding theory practical change architecture code see neural network behaves different activation function vanishing gradient problem loss function optimization method gradient descent momentum rmsprop adam learning rate decay xavier initialization introduction kera tensorflow tf deep learning kera tensorflow backend project work basic concept clustering mean clustering hierarchical clustering build hand project social medium analysis clustering principal component analysis pca learn math behind pca learn code plot pca recommendation engine understand netflix tech giant us recommendation engine content collaborative filtering pro con different approach recommendation engine market basket analysis apriori rule build recommender system image detection image classification localization introduction convolutional neural network cnn build handwritten digit recognizer cnn stride padding concept convolutional padding fully connected layer sliding window edge detection yolo algorithm look introduction classical network like lenet iou build image classifier cnn data augmentation technique natural language processing nlp introduction natural language processing nlp text preprocessing lemmatization stemming syntactical parsing entity parsing ctopic modelling latent dirichlet allocation lda collapsed gibbs sampling word embedding word vec cbow skipgram model restricted boltzman machine recurrent neural network rnn long short term memory lstm build chatbot concept nlp neural network history ai state art ai type agent type environment asymptotic notation uninformed search breadth first search uniform cost search depth first search depth limited search iterative deepening depth first search bidirectional search informed search greedy best first search search beyond local search hill climbing simulated annealing beam search genetic algorithm online search informed search min max tree alpha beta pruning move ordering stochastic game constraint satisfaction problem map coloring sudoku job scheduling constraint propagation backtracking passive reinforcement learning active reinforcement learning policy search mock interview mock interview mock interview mock interview',
#  'introduction big data machine learning understanding python type learning advice applying machine learning machine learning system design basic statistic data cleaning data exploration statistical inference pgm probabilistic graphical model regression simple linear regression multiple linear regression assessing performance ridge regression feature selection lasso nearest neighbour kernel regression classification decision tree cart support vector machine svm naive bayes project work cancer detection fraud analysis spam filter creation clustering overview type clustering type clustering algorithm mean clustering hierarchical clustering difference mean hierarchical clustering application clustering project work social medium analysis clustering recommender system overview phase recommendation process recommendation filtering technique evaluation metric recommendation algorithm spark core spark architecture working rdds machine learning spark – mllib perceptron learning procedure back propagation learning procedure learning feature vector word object recognition neural net optimization make learning go faster recurrent neural network recurrent neural network way make neural network generalize better combining multiple neural network improve generalization hopfield net boltzmann machine restricted boltzmann machine rbms stacking rbms make deep belief net deep learning convolutional neural network cnn object detetcion object classification localization edge detection stride padding yolo algorithm mock interview mock interview mock interview mock interview',
#  'introduction single page application development angular opinionated angular react vuejs ember angular framework react library typescript introduction npm angular npm ecosystem evaluation quiz installing angular cli package json building app using npm package json introduction angular module understanding base module application initializer module help create modular decoupled application understanding angular component create basic component display view component help create organized application using custom tag using root component initialize application evaluation quiz angular bootstrapping angular cli directory structure angular cli json file main main application file creating multiple module working module file understanding production dev environment scope inheritance controller using conditional statement ngif using template modifier directive looping data using ngfor understanding data binding working different data binding interpolation create component using cli regular code using import angular file using decorator angular component decorator using template html using cs file component constructor component ngoninit initialization evaulation quiz creating component inside module passing data component using input attaching event template working ngmodel passing data outside component using event emitter component hook different component hook use component lifecycle understanding component created attached destroyed inter component communication component talk using pipe angular inbuilt pipe angular working currency pipe working date pipe lower upper case pipe json pipe debugging creating custom pipe cli pipe decorator using transform function transform response creating custom pipe multiple argument evaluation quiz introduction service service singleton understanding dependency injection angular service way organize logic data service creating service using cli custom code working injectable decorator organizing service project code working inbuilt directive introduction custom directive api creating custom directive cli directive decorator creating custom directive code create directive modify html view elementref api renderer api creating event custom directive using hostlistener evaluation quiz working ngmodel template variable angular using template var ngmodel creating form working form event collecting handling form data form validation reactive form template form introduction reactive form creating form control code using using formgroup formcontrol formbuilder api creating dynamic control using formsgroup formscontrola form validation using validator function validators abstractcontrol validatorfn form validation using directive better approach handling event form evaluation quiz understanding observables subscriber introduction rxjs library map function introduction rest service using get post put delete need rest service traditional ajax approach difference httpmodule httpclient using http module connect server getting data sending custom header angular frontend using header class requestoptions class angular creating rest app using http module crud operation using httpclient talk server create entire rest app using httpclient module using interceptor securing server communication evaluation quiz introduction unit testing setting unit testing using karma creating unit test component creating unit test service evaluation quiz authentication using jwt securing angular application protecting attack deploying angular application working dist folder aot compilation optimizing angular app production mock interview mock interview mock interview mock interview',
#  'introduction webpack babel npm project structure first react app introduction role react problem react address react development environment node npm webpack babel babel presets jsx react component virtual dom change detection one way data binding component without state class function react component element instance jsx react createelement component lifecycle using prop data passing internal state class component ref input handling creating react app passing prop initializing state updating state parent child component main component router route indexroute authentication handling event react router implement react router master detail web application presentational component container component data fetching controlled component uncontrolled component materialui data behaviour data data mutation pure function redux architecture philosophy single immutable state pure impure function integration react provider store reducer action unique source truth provider connect application using react redux fetching data server redux introducing redux middleware exercise build redux middleware thunk action dispatch action exercise implement loading indicator using thunk mock interview mock interview mock interview mock interview',
#  'introduction single page application development angular opinionated angular react vuejs ember angular framework react library introduction npm angular npm ecosystem evaluation quiz installing angular cli package json building app using npm package json introduction angular module understanding base module application initializer module help create modular decoupled application understanding angular component create basic component display view component help create organized application using custom tag using root component initialize application evaluation quiz angular bootstrapping angular cli directory structure angular cli json file main main application file creating multiple module working module file understanding production dev environment scope inheritance controller using conditional statement ngif using template modifier directive looping data using ngfor understanding data binding working different data binding interpolation create component using cli regular code using import angular file using decorator angular component decorator using template html using cs file component constructor component ngoninit initialization evaulation quiz creating component inside module passing data component using input attaching event template working ngmodel passing data outside component using event emitter component hook different component hook use component lifecycle understanding component created attached destroyed inter component communication component talk using pipe angular inbuilt pipe angular working currency pipe working date pipe lower upper case pipe json pipe debugging creating custom pipe cli pipe decorator using transform function transform response creating custom pipe multiple argument evaluation quiz introduction service service singleton understanding dependency injection angular service way organize logic data service creating service using cli custom code working injectable decorator organizing service project code working inbuilt directive introduction custom directive api creating custom directive cli directive decorator creating custom directive code create directive modify html view elementref api renderer api creating event custom directive using hostlistener evaluation quiz working ngmodel template variable angular using template var ngmodel creating form working form event collecting handling form data form validation reactive form template form introduction reactive form creating form control code using using formgroup formcontrol formbuilder api creating dynamic control using formsgroup formscontrola form validation using validator function validators abstractcontrol validatorfn form validation using directive better approach handling event form evaluation quiz understanding observables subscriber introduction rxjs library map function introduction rest service using get post put delete need rest service traditional ajax approach difference httpmodule httpclient using http module connect server getting data sending custom header angular frontend using header class requestoptions class angular creating rest app using http module crud operation using httpclient talk server create entire rest app using httpclient module using interceptor securing server communication evaluation quiz introduction unit testing setting unit testing using karma creating unit test component creating unit test service evaluation quiz authentication using jwt securing angular application protecting attack deploying angular application working dist folder aot compilation optimizing angular app production introduction node importance asynchronous asynchronous javascript node event loop node process file system module reading directory reading file streaming building server creating server http receiving data http streaming working tcp commonjs module npm package event emitter api nodemon nodemailer socket io cryptography session handling cookie handling authentication connecting slack app introduction expressjs routing con ...
#  'cspring framework ioc dependency injection spring container beanfactory applicationcontext xmlbeanfactory classpathxmlapplicationcontext filesystemxmlapplicationcontext spring scope singleton prototype bean life cycle setup tear init method destroy method beanpostprocessor spring bean definition inheritance dependency injection constructor setter method injecting collection inner bean bean autowiring name type constructor annotation injection required true false autowiring setter property constructor qualifier component life cycle spring wiring loose coupling jdbctemplate\\xa update queryforobject preparedstatementcreator preparedstatementsetter datasource advice returning throwing around practical session model vew controller controller command class validator formcontroller exceptionresolver viewresolver mvc annotation controller requestmapping exceptionhandler orm jdbc hibernate transition pojo db mapping hibernate config file class annotation association persistence session sessionfactory transaction spring hibernate java persistence api entity primary key persistent field entity entity inheritance entity manager managing entity jpql service oriented architecture xml soap http web service description language wsdl universal description discovery integration representational state transfer restful webservices practical session mock interview mock interview mock interview mock interview',
#  'introduction python programming language introduces python basic data type file function error handling basic python syntax reading converting user input calculating stored value running python script python script unix window python editor ide language component control flow syntax intending statement relational operator logical operator true false bite wise operator loop break continue loop collection introduction list tuples set dictionary sorting dictionary copying collection summary string formatting string operation writing list tuples function sequence function method work sequence slice stride skipping around sequence manipulating list tuples list comprehension dicts working \\xa dicts applying dicts counting word complex application word pair frequency reading writing file flat file csv file excel file \\xa json file appending file seeking arbitrary position parsing technique large file installing different inbuilt package module per project requirement pywinauto pywin pyodbc win amd py mysql python ftputil py exe standard module importing module math module random module package composition function parameter functional documentation keyword optional parameter passing collection function variable number argument scope passing function function mapping function dictionary lambda closure variable scope returning single value multiple value handling different error exception achieve hassle free automation handling multiple exception standard exception hierarchy using module raise assert writing exception class designing custom logger mechanism record automation script flow launching external program operating system related task stdio system command walking directory random number date time introduction python class defining class initializes instance method property class method data static method private method inheritance\\xa polymorphism thread process threading library module thread synchronization queue standard library multiprocessing library module environment launching command creating process directory command miscellaneous call walking directory network programming introduction client server program evaluation client server working various secured third party apiôçös python intro relational database sql database mysql \\xa mongo db crud operation use inbuilt database module mysql alerting mail critical monitoring service python creating database project django installation required module installation creating project apps using django dev server development creating first web app django designing url writing handler view exception handling exposing http rest apis handling client http get post put update delete request processing data file providing json http creating activating model information insertion retrieval updation deletion using django object relation mapping orm exposing json data activating admin module managing user permission session handling building custom ui apps using admin module hosting client side code written using angularjs integration client side code server side django logging debugging purpose testing client apis deploying django application cloud elastic search kibana data analytics mock interview mock interview mock interview mock interview',
#  'html history timeline html design principle html html review doctype root element element content model new structural element html html comparison new element redefined element obsolete element html outline use feature detection technique feature detection example feature detection modernizr cs styling cs validating accessibility wai aria html form overview new input type contact info new input type native date picking opera rendering date input type new input type number range new attribute detecting support accessibility wai aria styling form element avoiding validation constraint validation api custom validation example audio video element using medium element attribute format serving device specific file accessibility backwards compatibility medium api rolling custom control canvas overview canvas element context coordinate system rectangle path path drawing method curve arc color style geolocation overview privacy concern api method api attribute using geolocation api success handler using geolocation api error handler using geolocation api third argument watchposition clearwatch fallback support geo local data storage overview web storage overview web storage api data type json javascript object notation accessing storage storage event database apis web worker overview worker message passing shared worker parent page latest standard cs cs cs border radius box shadow text shadow transition transforms gradient multiple background font face introduction installing bootstrap creating first page using bootstrap bootstrap container bootstrap grid system example grid system clearfix nested column typography handling table form handling horizontal form vertical form inline form input control icon form element button form validation handling image navigation item dropdown navbars modal carousel introduction javascript basic rule dot notation square bracket notation method property implicit window object getelementbyid method event handler javascript variable loosely typed language storing user entered data array declaring using array associative array understanding controller boundary scope array property method javascript operator javascript built function number object string object isnan object parsefloat parseint comparison passing value function note variable scope returning value function comparison string object math object date object us using type operator else else condition switch case loop syntax loop syntax loop syntax loop syntax understanding dom dom tree traversing dom accessing dom element modifying dom element using javascript accessing form data object cleaner validation validating radio button validating checkboxes validating select menu focus blur change event change validating text area introduction angularjs angularjs opinionated angularjs component architecture creating boundary using ng app model view controller template data binding repeating element template using expression cs class style using controller ui responsibility separation understanding controller boundary scope scope inheritance controller responding model change working inbuilt directive filter overview understanding filter expression building custom filter implementing filter custom filter example understanding built directive understanding routing angularjs using ngroute module creating route passing parameter route creating simple commerce front end page using angularjs dependency injection service factory provider modularity using service injecting service creating custom factory provider creating example using service directive overview creating directive directive definition object compilation linking creating component implementing directive example app understanding server communicating angular communicating http installation configuration apache administration virtual host alias directory protection cgi apache module common apache module apache config file variable overwriting config value using htaccess file user webpage wamp  ...
#  'java oops concept need java class interface object constructor field method variable keywords inheritance method overloading overriding access specifier jar file package comparing printing object final variable initializing bitwise operation operator data type generic type date calendar inner anonymous class string string buffer \\xa array switch statement exception reflection clone assertion file handling io package class enum type multi threading concurrency data structure collection framework sorting jdbc sql database concept driver servlets webserver http method javaserver page jsp jstl java cryptography encryption java mail cryptographic protocol jms xml cspring framework ioc dependency injection spring container beanfactory applicationcontext xmlbeanfactory classpathxmlapplicationcontext filesystemxmlapplicationcontext spring scope singleton prototype bean life cycle setup tear init method destroy method beanpostprocessor spring bean definition inheritance dependency injection constructor setter method injecting collection inner bean bean autowiring name type constructor annotation injection required true false autowiring setter property constructor qualifier component life cycle spring wiring loose coupling jdbctemplate ôçô update queryforobject preparedstatementcreator preparedstatementsetter datasource advice returning throwing around practical session model vew controller controller command class validator formcontroller exceptionresolver viewresolver mvc annotation controller requestmapping exceptionhandler orm jdbc hibernate transition pojo db mapping hibernate config file class annotation association persistence session sessionfactory transaction spring hibernate java persistence api entity primary key persistent field entity entity inheritance entity manager managing entity jpql service oriented architecture xml soap http web service description language ôçô wsdl universal description discovery integration representational state transfer restful webservices mock interview mock interview mock interview mock interview',
#  'introduction javascript basic rule dot notation square bracket notation method property implicit window object getelementbyid method event handler javascript variable loosely typed language storing user entered data array declaring using array associative array array property method javascript operator javascript built function number object string object isnan object parsefloat parseint comparison passing value function note variable scope returning value function comparison string object math object date object us using type operator else else condition switch case loop syntax loop syntax loop syntax loop syntax understanding dom dom tree traversing dom accessing dom element modifying dom element using javascript accessing form data object cleaner validation validating radio button validating checkboxes validating select menu focus blur change event change validating text area understanding class creating class variable public private variable class member public private member javascript inner function class member using object context creating class template using javascript understanding constructor creating object using constructor object creation constructor literal literal constructor understanding class property creating property class accessing property outside class using object public property li private property specific use case private property understanding method function class creating method accessing method outside class public private method using public method outside class private method use case class specific computation using private method understanding inheritance javascript implementing inheritance javascript single multiple inheritance javascript prototypal inheritance restricting inheritance understand object javascript creating object using literal creating object using constructor function understanding creating inner function using member variable object initialization literal understanding object context inside member function using apply using apply transfer context object context class function understanding variable declaration declaration diff type language variable hoisting function variable hoisting scenario understanding function variable javascript immediate function using immediate function clean global namespace using namespaces javascript anonymous function application assigning value function variable closure closure application closure loop scope chain getters setter iterators eval understanding prototype enumerable property iterating property understanding proto proto chain proto hierarchy browser environment proto behaviour understanding inheritance javascript inheritance using prototype inheritance using temporary constructor creating extend function inheritance creating super javascript object shallow copy object deep copy multiple inheritance parasitic inheritance mock interview mock interview mock interview mock interview',
#  'installation configuration apache administration virtual host alias directory protection cgi apache module common apache module apache config file variable overwriting config value using htaccess file user webpage wamp installation wamp component configuring apache wamp configuring php wamp mysql basic configuration upgrading downgrading version wamp hand session installing development environ php mysql apache post install configuration php ini file enabling disabling feature important tag php ini file understanding httpd conf file fine tuning apache environmental security consideration unix linux exercise project defining array php list hash use list array hash extracting array element loop catching list element separate variable using split list extracting hash element loop using value extracting hash key loop using key extraction value key using value key syntax serializing un serializing array hash storing array disk file using later passing array reference value function array function array split array chunk array count value array fill array key exists array pop array push etc merging array basic defining php class constructor default constructor desconstructor php public private protected variable including external class file function overloading inheritance example class using sample user class requireôçø ôç£includeôçø ôç£include onceôçø hand session auto loading class object using static keyword class scope resolution class constant abstract class concept demo interface concept demo object iteration pattern magic method using final keyword object cloning basic pre defined variable variable scope using global keyword globals writing user defined function many different way write php function passing argument returning value returning multiple value default parameter precaution filesystem basename copy dirname fopen fread fwrite foef fclose fgets file filesize fputs dir file executable stat string trim echo explode fprintf implode join md str word count strlen substr substr replace wordwrap http header base encode base decode parse url urlencode urldecode file upload post method uploads error message mathematical function ab sin co tan pi pow min max log log hexdec exp deg rad rad deg srand rand round nan infinite finite fmod floor ceil sqrt writing user defined function many different way write php function passing argument returning value returning multiple value default parameter precaution filesystem basename copy dirname fopen fread fwrite foef fclose fgets file filesize fputs dir file executable stat string trim echo explode fprintf implode join md str word count strlen substr substr replace wordwrap http header base encode base decode parse url urlencode urldecode file upload post method uploads error message mathematical function ab sin co tan pi pow min max log log hexdec exp deg rad rad deg srand rand round nan infinite finite fmod floor ceil sqrt understanding form input field reading form variable php using post method reading variable php using get method carrying value one page another using query string php session cooky concept database abstraction implementing db class mysql example making database query using implementing db class changing db class work sqlite understanding ajax using php ajax using javascript pas variable php using php render javascript demo login using php ajax passing variable php javascript another approach using cooky implementing working soap client server using nusoap implementing working xml rpc client server using pear practice web service writing new working service introduction framework introduction mvc design pattern working controller view understanding templating introduction mvc design pattern introduction laravel understanding composer installing laravel understanding laravel directory structure creating starter app using laravel working database migration understanding controller laravel working controller understanding view laravel creating view class understandi ...
#  'drupal began drupal drupal version difference technology drupal use drupal architecture drupal content management system content management framework web application framework module theme node block bootstrap hook callback configuring wamp drupal installing drupal admin interface creating content managing content site building site configuration user management report help core required core optional enabled core optional disabled downloading enabling drupal search working indexing cron popular module module selection evaluation job site setup block region default block custom block configuring block enabling default block controlling front page download method file module image module storing user uploaded material page article creating custom content type adding field content type text field adding field content type contributed module link field adding field content type contributed module image field adding field content type contributed module medium field adding field content type contributed module field group adding field content type contributed module node reference manage display\\xa setting teaser body display label display format taxonomy vocabulary required vocabulary controlled vocabulary term single multiple term adding term view content term storing taxonomy module based vocabulary common function overview view view type default view view type override view view type normal view view handler display basic setting job based site setup job search listing display display type feed view creation basic setting view creation field node view creation filter view creation argument view creation relationship overview panel panel layout panel page introduction solr search installation solr integration drupal search panel view argument social networking site setup messaging instant messaging profile architecture theme system theme template info file theme engine hook theme creation file installing theme creating enabling customized subtheme theme inheritance subthemes modifying base theme theming custom stylesheet implementation hierarchy preprocess hook theme preprocessors hook overriding theme behavior php networking site custom theme view coding hook \\xa menu system permission working drupal database api creating simple hello world module form processing validation form submission redirection caching module using inbuilt cache creating basic form module template passing data template module drupal basic caching block level caching using page boost memcached introduction installation working drush deploying drupal application porting working nodeapi form alter advanced hook hr portal setup introduction drupal drupal drupal drupal architecture drupal admin panel understanding drupal upgrade process understanding yaml file drupal configuration process drupal deployment theme customization theme development module development securing drupal site',
#  'html history timeline html design principle html html review doctype root element element content model new structural element html html comparison new element redefined element obsolete element html outline use feature detection technique feature detection example feature detection modernizr cs styling validating accessibility wai aria html form overview new input type contact info new input type native date picking opera rendering date input type new input type number range new attribute detecting support accessibility wai aria styling form element avoiding validation constraint validation api custom validation example audio video element using medium element attribute format serving device specific file accessibility backwards compatibility medium api rolling custom control canvas overview canvas element context coordinate system rectangle path path drawing method curve arc color style geolocation overview privacy concern api method api attribute using geolocation api success handler using geolocation api error handler using geolocation api third argument watchposition clearwatch fallback support geo local data storage overview web storage overview web storage api data type json javascript object notation accessing storage storage event database apis web worker overview worker message passing shared worker parent page',
#  'jquery fundamental need jquery jquery alternative document ready handler making dom element selecting element manipulation using basic cs selector using child container attribute selector selecting position searching element jquery searching parent child element search traversing element selecting child parent element generating new html dom manipulation using jquery multiple dom manipulation function event handling jquery handling click blur submit related event event delegation introduction ajax making get request ajax making post request making rest request understanding jsonp cross domain request promise api understanding promise deferred object creating asynchronous workflow promise api handling multiple request deferred promise creating jquery plugins optimizing jquery security jquery responding model change working inbuilt directive mock interview mock interview mock interview mock interview mock interview mock interview mock interview mock interview',
#  'history difference linux window difference linux unix gnu usage career option interesting fact linux linux virus proof various linux distribution pro con mkdir touch pwd cd chmod df du dd adduser sort passwd rm rmdir date vi editor file structure hierarchy file permission lvm overview cron rpm make boot loader lilo grub system initialization inittab rc sysinit rc volume group physical logical volume resizing lvs etc route ifconfig ping netstat modprobe rmmod insmod lsmod modinfo ssh sshd scp single user mode rescue mode ip table file sharing samba nfs mail server using sendmail web server installation apache proxy server installation using squid firewalling using iptables pam plug gable authentication module linux performance monitor sar utility monitor cpu using sar track application causing memory leak awk sed grep echo variable function lynis unix based auditing tool rootkit hunter',
#  'introduction angularjs angularjs opinionated angularjs component architecture creating boundary using ng app model view controller template data binding repeating element template using expression cs class style using controller ui responsibility separation understanding controller boundary scope scope inheritance controller responding model change working inbuilt directive filter overview understanding filter expression building custom filter implementing filter custom filter example understanding built directive understanding routing angularjs using ngroute module creating route passing parameter route creating simple commerce front end page using angularjs dependency injection service factory provider modularity using service injecting service creating custom factory provider creating example using service directive overview creating directive directive definition object compilation linking creating component implementing directive example app understanding server communicating angular communicating http configuring request sending http header caching response request response transformation working get fetch data post put delete testing model using jasmine creating unit test angularjs component using protractor end end testing creating end end test angularjs creating advanced route using ui router using local storage angularjs script optimization securing angularjs application introduction ionic framework installation configuring ionic creating apps using ionic using ionic command line deploying sample application using ionic creating simple ionic application using angularjs mock interview mock interview mock interview mock interview',
#  'web programming introduction client server architecture html javascript body document javascript event handling javascript clientside validation introduction asp net mvc first mvc web application view mvc application adding model mvc application controller actionresult type passing data view controller action selector httpget httppost built action filter understanding custom action filter user agent action filter example asynchronous controller razor introduction syntax working layout page partial view type view introducing html helper method binding html helper viewdata binding html helper model display editor helper method custom template display editor method default behaviour default model binder bind attribute introduction validating model data remote custom validation attribute custom clientside validation web configuration file custom error handling cookie cooky example understanding session login example using session working session property handling global data web application entity framework crud operation writing using business object writing using generic repository caching repository dependency injection custom controller factory url routing routing feature mvc ajax helper method bundling minification web api introduction simple web api example jquery client crud operation using webapi unit testing class unit testing controller mvc ntier layered architecture part ntier layered architecture part sample small project',
#  'software testing important waterfall model sdlc model sdlc agile model sdlc type requirement test strategy create efficient test strategy unit testing integration testing smoke testing system testing regression testing acceptance testing black box testing white box testing are\\xa test case functional test case performance test case security test case ui test case defect verification defect life cycle defect reporting tracking test summary test report preparation automation testing important learn automation limitation manual testing limitation automation testing need automate selenium kind testing perform using selenium advantage selenium difference selenium qtp ide selenium rc selenium grid selenium webdriver selenium selenium ide install selenium ide recording playback using selenium ide ide context menu action accessors assertion selenium ide verify selenium ide difference assert verify selenium ide add comment selenium ide create test case save test case selenium ide creating test suite selenium ide import test case test suite selenium ide take screenshots selenium ide limitation selenium ide important selenium ide command open click clickandwait type typekeys verifytitle asserttitle verifytextpresent verifyelementpresent verifytable waitforpagetoload waitforelementpresent goback pause captureentirepagescreenshotandwait tool identify element object firebug xpath locate element using xpath locate element using cs advantage disadvantage using xpath cs locate element id locate element name locate element link text use selenium webdriver industry difference selenium rc selenium webdriver configure selenium webdriver eclipse browser automate using selenium webdriver create script selenium webdriver automate form using selenium webdriver find broken link application using selenium webdriver automate alert using selenium webdriver automate checkbox using selenium webdriver automate dropdown using selenium webdriver automate frame using selenium webdriver give implicit explicit wait selenium webdriver capture screenshots selenium webdriver limitation selenium webdriver testng framework testng used testng make automation easy advantage using testng junit install testng eclipse annotation testng creating running simple test script using testng prioritize execution test testng hard soft assertion testng create testng xml file execute multiple test case using testng xml create test suite using testng xml advantage testng xml file perform cross browser testing using testng generating test report using testng including poi jar file project write java program read data excel sheet create property file java read data property file autoit used selenium download autoit check help section autoit use finder tool autoit create autoit script integrate autoit selenium important method used autoit maven selenium configure maven eclipse create build maven execute build maven analyze report using maven jenkins selenium download install jenkins configure jenkins create batch file execute jenkins job downloading configuring github basic git command working repository creating repository committing syncing code reverting rolling back code resolving conflict installing java installing eclipse feature java java selenium first java program data type java string class statement conditional concatenation operator loop loop practical example loop usage loop selenium creating object java local variable global variable oops concept constructor concept inheritance working example interface overloading overriding function accessing modifiers\\xa public private default protected ôçô exception handling java data driven framework keyword driven framework hybrid framework difference data driven keyword driven hybrid framework object repository selenium framework design keyword driven framework staging zenrays com website',
#  'software testing important waterfall model sdlc model sdlc agile model sdlc type requirement test strategy create efficient test strategy unit testing integration testing smoke testing system testing regression testing acceptance testing black box testing white box testing are\\xa test case functional test case performance test case security test case ui test case defect verification defect life cycle defect reporting tracking test summary test report preparation',
#  'automation testing important learn automation limitation manual testing limitation automation testing need automate selenium kind testing perform using selenium advantage selenium difference selenium qtp ide selenium rc selenium grid selenium webdriver selenium selenium ide install selenium ide recording playback using selenium ide ide context menu action accessors assertion selenium ide verify selenium ide difference assert verify selenium ide add comment selenium ide create test case save test case selenium ide creating test suite selenium ide import test case test suite selenium ide take screenshots selenium ide limitation selenium ide important selenium ide command open click clickandwait type typekeys verifytitle asserttitle verifytextpresent verifyelementpresent verifytable waitforpagetoload waitforelementpresent goback pause captureentirepagescreenshotandwait tool identify element object firebug xpath locate element using xpath locate element using cs advantage disadvantage using xpath cs locate element id locate element name locate element link text use selenium webdriver industry difference selenium rc selenium webdriver configure selenium webdriver eclipse browser automate using selenium webdriver create script selenium webdriver automate form using selenium webdriver find broken link application using selenium webdriver automate alert using selenium webdriver automate checkbox using selenium webdriver automate dropdown using selenium webdriver automate frame using selenium webdriver give implicit explicit wait selenium webdriver capture screenshots selenium webdriver limitation selenium webdriver testng framework testng used testng make automation easy advantage using testng junit install testng eclipse annotation testng creating running simple test script using testng prioritize execution test testng hard soft assertion testng create testng xml file execute multiple test case using testng xml create test suite using testng xml advantage testng xml file perform cross browser testing using testng generating test report using testng including poi jar file project write java program read data excel sheet create property file java read data property file autoit used selenium download autoit check help section autoit use finder tool autoit create autoit script integrate autoit selenium important method used autoit maven selenium configure maven eclipse create build maven execute build maven analyze report using maven jenkins selenium download install jenkins configure jenkins create batch file execute jenkins job downloading configuring github basic git command working repository creating repository committing syncing code reverting rolling back code resolving conflict installing java installing eclipse feature java java selenium first java program data type java string class statement conditional concatenation operator loop loop practical example loop usage loop selenium creating object java local variable global variable oops concept constructor concept inheritance working example interface overloading overriding function accessing modifiers\\xa public private default protected ôçô exception handling java data driven framework keyword driven framework hybrid framework difference data driven keyword driven hybrid framework object repository selenium framework design keyword driven framework staging zenrays com website',
#  'getting started using vuejs interact dom using conditionals rendering list first course project\\ —\\ athe monster slayer understanding vuejs instance moving “ real ” development workflow webpack vue cli introduction component communicating component advanced component usage second course project\\ —\\ awonderful quote handling user input form using creating directive improving app filter mixins adding animation transition connecting server via http\\ —\\ ausing vue resource routing vuejs application better state management vuex final project\\ —\\ athe stock trader deploying vuejs application course roundup',
#  'java oops concept need java class interface object constructor field method variable keywords inheritance method overloading overriding access specifier jar file javadoc api creation package comparing printing object final variable initializing bitwise operation operator data type generic type date calendar joda inner anonymous class string string buffer regular expression array switch statement exception reflection clone assertion file handling io package class enum type multi threading concurrency data structure collection framework sorting jdbc sql database concept driver socket remote communication servlets webserver http method rmi networking javaserver page jsp jstl java cryptography encryption java mail cryptographic protocol jms xml cspring framework ioc dependency injection spring container beanfactory applicationcontext xmlbeanfactory classpathxmlapplicationcontext filesystemxmlapplicationcontext spring scope singleton prototype bean life cycle setup tear init method destroy method beanpostprocessor spring bean definition inheritance dependency injection constructor setter method injecting collection inner bean bean autowiring name type constructor annotation injection required true false autowiring setter property constructor qualifier component life cycle spring wiring loose coupling jdbctemplate ôçô update queryforobject preparedstatementcreator preparedstatementsetter datasource advice returning throwing around practical session model vew controller controller command class validator formcontroller exceptionresolver viewresolver mvc annotation controller requestmapping exceptionhandler orm jdbc hibernate transition pojo db mapping hibernate config file class annotation association persistence session sessionfactory transaction spring hibernate java persistence api entity primary key persistent field entity entity inheritance entity manager managing entity jpql practical session',
#  'introduction nodejs importance asynchronous asynchronous javascript nodejs event loop nodejs process file system module reading directory reading file streaming building server creating server http receiving data http streaming working tcp commonjs module npm package eventemitter api introduction expressjs routing configuration view middleware working data working socket io process cluster child process module cluster cluster object worker object best practice npm node api design error handling debugging hosting node need host forever pm node window node window service iisnode unit testing mock interview mock interview mock interview mock interview']

# %%
words = set(nltk.corpus.words.words())
clean = []
for i in clean_course_content1:
    clean.append(" ".join(w for w in nltk.wordpunct_tokenize(i) if w.lower() in words or not w.isalpha()))

# %%
clean
# Out:
# ['require ai problem traditional system opportunity ai need excel logical mind tool efficiently build model python popular understand actually model handle data data type model unsupervised peek reinforcement learning break data training test cross validation technique understand linear regression gradient descent actual hand understand calculation behind gradient descent brush differentiation understand math behind hand code python learn improve model one difficult aspect learn building model use linear regression model understand learn hand avoid bias variance regularization ridge lasso test logistic regression understand classification logistic regression maximum likelihood estimation build end end model logistic regression learn hand actually build model industry code interview data science competition probability based model decision tree model understand concept entropy impurity information gain detailed hand project predict possible loan defaulter large national bank apply concept improve decision tree model without bagging random forest gradient boost understand distance based model choose value project work breast cancer power model can not popular industry learn kernel function different kernel function build optical character reader help kernel function neural network neural network actually solve complex pattern build neural network architecture neural network mimic cognitive capability human build logic gate neural network understand forward backward propagation plot neural network code map understanding theory practical change architecture code see neural network different activation function vanishing gradient problem loss function optimization method gradient descent momentum learning rate decay introduction deep learning project work basic concept clustering mean clustering hierarchical clustering build hand project social medium analysis clustering principal component analysis learn math behind learn code plot recommendation engine understand tech giant us recommendation engine content collaborative filtering pro con different approach recommendation engine market basket analysis apriori rule build recommender system image detection image classification localization introduction convolutional neural network build digit recognizer stride padding concept convolutional padding fully connected layer sliding window edge detection algorithm look introduction classical network like build image classifier data augmentation technique natural language introduction natural language text stemming syntactical entity latent allocation sampling word word model restricted machine recurrent neural network long short term memory build concept neural network history ai state art ai type agent type environment asymptotic notation uninformed search breadth first search uniform cost search depth first search depth limited search iterative deepening depth first search bidirectional search informed search greedy best first search search beyond local search hill climbing beam search genetic algorithm search informed search min tree alpha beta pruning move stochastic game constraint satisfaction problem map coloring job constraint propagation passive reinforcement learning active reinforcement learning policy search mock interview mock interview mock interview mock interview',
#  'introduction big data machine learning understanding python type learning advice machine learning machine learning system design basic statistic data cleaning data exploration statistical inference probabilistic graphical model regression simple linear regression multiple linear regression performance ridge regression feature selection lasso nearest kernel regression classification decision tree cart support vector machine naive project work cancer detection fraud analysis filter creation clustering overview type clustering type clustering algorithm mean clustering hierarchical clustering difference mean hierarchical clustering application clustering project work social medium analysis clustering recommender system overview phase recommendation process recommendation filtering technique evaluation metric recommendation algorithm spark core spark architecture working machine learning spark – learning procedure back propagation learning procedure learning feature vector word object recognition neural net optimization make learning go faster recurrent neural network recurrent neural network way make neural network generalize better combining multiple neural network improve generalization net machine restricted machine make deep belief net deep learning convolutional neural network object object classification localization edge detection stride padding algorithm mock interview mock interview mock interview mock interview',
#  'introduction single page application development angular opinionated angular react ember angular framework react library typescript introduction angular ecosystem evaluation quiz angular package building package introduction angular module understanding base module application module help create modular application understanding angular component create basic component display view component help create organized application custom tag root component initialize application evaluation quiz angular angular directory structure angular file main main application file multiple module working module file understanding production dev environment scope inheritance controller conditional statement template modifier directive looping data understanding data binding working different data binding interpolation create component regular code import angular file decorator angular component decorator template file component constructor component quiz component inside module passing data component input event template working passing data outside component event emitter component hook different component hook use component understanding component attached inter component communication component talk pipe angular inbuilt pipe angular working currency pipe working date pipe lower upper case pipe pipe custom pipe pipe decorator transform function transform response custom pipe multiple argument evaluation quiz introduction service service singleton understanding dependency injection angular service way organize logic data service service custom code working injectable decorator service project code working inbuilt directive introduction custom directive custom directive directive decorator custom directive code create directive modify view renderer event custom directive evaluation quiz working template variable angular template form working form event handling form data form validation reactive form template form introduction reactive form form control code dynamic control form validation function form validation directive better approach handling event form evaluation quiz understanding subscriber introduction library map function introduction rest service get post put delete need rest service traditional approach difference module connect server getting data sending custom header angular header class class angular rest module operation talk server create entire rest module interceptor server communication evaluation quiz introduction unit testing setting unit testing karma unit test component unit test service evaluation quiz authentication angular application protecting attack angular application working folder compilation angular production mock interview mock interview mock interview mock interview',
#  'introduction project structure first react introduction role react problem react address react development environment node react component virtual dom change detection one way data binding component without state class function react component element instance react component prop data passing internal state class component ref input handling react passing prop state state parent child component main component router route authentication handling event react router implement react router master detail web application presentational component container component data fetching component uncontrolled component data behaviour data data mutation pure function redux architecture philosophy single immutable state pure impure function integration react provider store reducer action unique source truth provider connect application react redux fetching data server redux redux exercise build redux action dispatch action exercise implement loading indicator mock interview mock interview mock interview mock interview',
#  'introduction single page application development angular opinionated angular react ember angular framework react library introduction angular ecosystem evaluation quiz angular package building package introduction angular module understanding base module application module help create modular application understanding angular component create basic component display view component help create organized application custom tag root component initialize application evaluation quiz angular angular directory structure angular file main main application file multiple module working module file understanding production dev environment scope inheritance controller conditional statement template modifier directive looping data understanding data binding working different data binding interpolation create component regular code import angular file decorator angular component decorator template file component constructor component quiz component inside module passing data component input event template working passing data outside component event emitter component hook different component hook use component understanding component attached inter component communication component talk pipe angular inbuilt pipe angular working currency pipe working date pipe lower upper case pipe pipe custom pipe pipe decorator transform function transform response custom pipe multiple argument evaluation quiz introduction service service singleton understanding dependency injection angular service way organize logic data service service custom code working injectable decorator service project code working inbuilt directive introduction custom directive custom directive directive decorator custom directive code create directive modify view renderer event custom directive evaluation quiz working template variable angular template form working form event handling form data form validation reactive form template form introduction reactive form form control code dynamic control form validation function form validation directive better approach handling event form evaluation quiz understanding subscriber introduction library map function introduction rest service get post put delete need rest service traditional approach difference module connect server getting data sending custom header angular header class class angular rest module operation talk server create entire rest module interceptor server communication evaluation quiz introduction unit testing setting unit testing karma unit test component unit test service evaluation quiz authentication angular application protecting attack angular application working folder compilation angular production introduction node importance asynchronous asynchronous node event loop node process file system module reading directory reading file streaming building server server data streaming working module package event emitter socket io cryptography session handling handling authentication slack introduction routing configuration view working data working socket io process cluster child process module cluster cluster object worker object best practice node design error handling hosting node need host forever node window node window service unit testing exception handling unit testing event loop rest token based authentication promise closure introduction create create table insert select query sort delete drop update limit join advance concept map reduce hand application chat application book show mock interview mock interview mock interview mock interview',
#  'framework dependency injection spring container spring scope singleton prototype bean life cycle setup tear method destroy method spring bean definition inheritance dependency injection constructor setter method collection inner bean bean name type constructor annotation injection true false setter property constructor qualifier component life cycle spring wiring loose coupling \\ update advice throwing around practical session model controller controller command class annotation controller hibernate transition hibernate file class annotation association persistence session transaction spring hibernate persistence entity primary key persistent field entity entity inheritance entity manager entity service architecture soap web service description language universal description discovery integration representational state transfer restful practical session mock interview mock interview mock interview mock interview',
#  'introduction python language python basic data type file function error handling basic python syntax reading converting user input calculating value running python script python script window python editor ide language component control flow syntax intending statement relational operator logical operator true false bite wise operator loop break continue loop collection introduction list set dictionary dictionary collection summary string string operation writing list function sequence function method work sequence slice stride skipping around sequence list list comprehension working \\ counting word complex application word pair frequency reading writing file flat file file excel file \\ file file seeking arbitrary position technique large file different inbuilt package module per project requirement win python standard module module math module random module package composition function parameter functional documentation optional parameter passing collection function variable number argument scope passing function function function dictionary lambda closure variable scope single value multiple value handling different error exception achieve hassle free handling multiple exception standard exception hierarchy module raise assert writing exception class designing custom logger mechanism record script flow external program operating system related task system command walking directory random number date time introduction python class class instance method property class method data static method private method inheritance \\ polymorphism thread process library module thread synchronization queue standard library library module environment command process directory command miscellaneous call walking directory network introduction client server program evaluation client server working various third party python relational \\ operation use inbuilt module mail critical service python project installation module installation project dev server development first web designing writing handler view exception handling rest handling client get post put update delete request data file providing model information insertion retrieval deletion object relation data module user permission session handling building custom module hosting client side code written integration client side code server side logging purpose testing client application cloud elastic search data analytics mock interview mock interview mock interview mock interview',
#  'history design principle review root element element content model new structural element comparison new element element obsolete element outline use feature detection technique feature detection example feature detection styling accessibility aria form overview new input type contact new input type native date opera rendering date input type new input type number range new attribute support accessibility aria styling form element validation constraint validation custom validation example audio video element medium element attribute format serving device specific file accessibility backwards compatibility medium rolling custom control canvas overview canvas element context system rectangle path path drawing method curve arc color style overview privacy concern method attribute success handler error handler third argument fallback support geo local data storage overview web storage overview web storage data type object notation storage storage event web worker overview worker message passing worker parent page latest standard border radius box shadow text shadow transition gradient multiple background font face introduction bootstrap first page bootstrap bootstrap container bootstrap grid system example grid system column typography handling table form handling horizontal form vertical form form input control icon form element button form validation handling image navigation item modal introduction basic rule dot notation square bracket notation method property implicit window object method event handler variable loosely language user data array array associative array understanding controller boundary scope array property method operator built function number object string object object comparison passing value function note variable scope value function comparison string object math object date object us type operator else else condition switch case loop syntax loop syntax loop syntax loop syntax understanding dom dom tree traversing dom dom element dom element form data object cleaner validation radio button select menu focus blur change event change text area introduction opinionated component architecture boundary model view controller template data binding element template expression class style controller responsibility separation understanding controller boundary scope scope inheritance controller model change working inbuilt directive filter overview understanding filter expression building custom filter filter custom filter example understanding built directive understanding routing module route passing parameter route simple commerce front end page dependency injection service factory provider service service custom factory provider example service directive overview directive directive definition object compilation linking component directive example understanding server communicating angular communicating installation configuration apache administration virtual host alias directory protection apache module common apache module apache file variable value file user wamp installation wamp component apache wamp wamp basic configuration version wamp hand session development environ apache post install configuration file feature important tag file understanding file fine tuning apache environmental security consideration exercise project array list hash use list array hash array element loop catching list element separate variable split list hash element loop value hash key loop key extraction value key value key syntax un array hash array disk file later passing array reference value function array function array split array chunk array count value array fill array key array pop array push array basic class constructor default constructor destructor public private variable external class file function inheritance example class sample user class £ £ include hand session auto loading class object static class scope resolution class constant abstract class concept interface concept object iteration pattern magic method f ...
#  'concept need class interface object constructor field method variable inheritance method access specifier jar file package printing object final variable bitwise operation operator data type generic type date calendar inner anonymous class string string buffer \\ array switch statement exception reflection clone assertion file handling io package class type concurrency data structure collection framework concept driver method page cryptography encryption mail cryptographic protocol framework dependency injection spring container spring scope singleton prototype bean life cycle setup tear method destroy method spring bean definition inheritance dependency injection constructor setter method collection inner bean bean name type constructor annotation injection true false setter property constructor qualifier component life cycle spring wiring loose coupling update advice throwing around practical session model controller controller command class annotation controller hibernate transition hibernate file class annotation association persistence session transaction spring hibernate persistence entity primary key persistent field entity entity inheritance entity manager entity service architecture soap web service description language universal description discovery integration representational state transfer restful mock interview mock interview mock interview mock interview',
#  'introduction basic rule dot notation square bracket notation method property implicit window object method event handler variable loosely language user data array array associative array array property method operator built function number object string object object comparison passing value function note variable scope value function comparison string object math object date object us type operator else else condition switch case loop syntax loop syntax loop syntax loop syntax understanding dom dom tree traversing dom dom element dom element form data object cleaner validation radio button select menu focus blur change event change text area understanding class class variable public private variable class member public private member inner function class member object context class template understanding constructor object constructor object creation constructor literal literal constructor understanding class property property class property outside class object public property li private property specific use case private property understanding method function class method method outside class public private method public method outside class private method use case class specific computation private method understanding inheritance inheritance single multiple inheritance prototypal inheritance inheritance understand object object literal object constructor function understanding inner function member variable object literal understanding object context inside member function apply apply transfer context object context class function understanding variable declaration declaration type language variable hoisting function variable hoisting scenario understanding function variable immediate function immediate function clean global anonymous function application value function variable closure closure application closure loop scope chain setter understanding prototype enumerable property property understanding proto proto chain proto hierarchy browser environment proto behaviour understanding inheritance inheritance prototype inheritance temporary constructor extend function inheritance super object shallow copy object deep copy multiple inheritance parasitic inheritance mock interview mock interview mock interview mock interview',
#  'installation configuration apache administration virtual host alias directory protection apache module common apache module apache file variable value file user wamp installation wamp component apache wamp wamp basic configuration version wamp hand session development environ apache post install configuration file feature important tag file understanding file fine tuning apache environmental security consideration exercise project array list hash use list array hash array element loop catching list element separate variable split list hash element loop value hash key loop key extraction value key value key syntax un array hash array disk file later passing array reference value function array function array split array chunk array count value array fill array key array pop array push array basic class constructor default constructor public private variable external class file function inheritance example class sample user class £ £ include hand session auto loading class object static class scope resolution class constant abstract class concept interface concept object iteration pattern magic method final object basic defined variable variable scope global writing user defined function many different way write function passing argument value multiple value default parameter precaution copy file file executable string trim echo explode implode join word count replace header base encode base decode parse file post method error message mathematical function sin tan pi pow min log log deg rad rad deg rand round nan infinite finite floor ceil writing user defined function many different way write function passing argument value multiple value default parameter precaution copy file file executable string trim echo explode implode join word count replace header base encode base decode parse file post method error message mathematical function sin tan pi pow min log log deg rad rad deg rand round nan infinite finite floor ceil understanding form input field reading form variable post method reading variable get method carrying value one page another query string session cooky concept abstraction class example making query class class work understanding variable render login passing variable another approach cooky working soap client server working client server pear practice web service writing new working service introduction framework introduction design pattern working controller view understanding introduction design pattern introduction understanding composer understanding directory structure starter working migration understanding controller working controller understanding view view class understanding model model class working blade template understanding test driven development writing test application complete flow controller view model understanding rest service rest service mock interview mock interview mock interview mock interview',
#  'drupal drupal drupal version difference technology drupal use drupal architecture drupal content management system content management framework web application framework module theme node block bootstrap hook wamp drupal drupal interface content content site building site configuration user management report help core core optional core optional disabled drupal search working indexing popular module module selection evaluation job site setup block region default block custom block block default block front page method file module image module user material page article custom content type field content type text field field content type module link field field content type module image field field content type module medium field field content type module field group field content type module node reference manage display \\ setting teaser body display label display format taxonomy vocabulary vocabulary vocabulary term single multiple term term view content term taxonomy module based vocabulary common function overview view view type default view view type override view view type normal view view handler display basic setting job based site setup job search listing display display type feed view creation basic setting view creation field node view creation filter view creation argument view creation relationship overview panel panel layout panel page introduction search installation integration drupal search panel view argument social site setup instant profile architecture theme system theme template file theme engine hook theme creation file theme theme inheritance base theme custom implementation hierarchy hook theme hook theme behavior site custom theme view hook \\ menu system permission working drupal simple hello world module form validation form submission redirection module inbuilt cache basic form module template passing data template module drupal basic block level page boost introduction installation working drupal application working form alter advanced hook portal setup introduction drupal drupal drupal drupal architecture drupal panel understanding drupal upgrade process understanding file drupal configuration process drupal deployment theme theme development module development drupal site',
#  'history design principle review root element element content model new structural element comparison new element element obsolete element outline use feature detection technique feature detection example feature detection styling accessibility aria form overview new input type contact new input type native date opera rendering date input type new input type number range new attribute support accessibility aria styling form element validation constraint validation custom validation example audio video element medium element attribute format serving device specific file accessibility backwards compatibility medium rolling custom control canvas overview canvas element context system rectangle path path drawing method curve arc color style overview privacy concern method attribute success handler error handler third argument fallback support geo local data storage overview web storage overview web storage data type object notation storage storage event web worker overview worker message passing worker parent page',
#  'fundamental need alternative document ready handler making dom element element manipulation basic selector child container attribute selector position searching element searching parent child element search traversing element child parent element generating new dom manipulation multiple dom manipulation function event handling handling click blur submit related event event delegation introduction making get request making post request making rest request understanding cross domain request promise understanding promise deferred object asynchronous promise handling multiple request deferred promise security model change working inbuilt directive mock interview mock interview mock interview mock interview mock interview mock interview mock interview mock interview',
#  'history difference window difference gnu usage career option interesting fact virus proof various distribution pro con touch sort date editor file structure hierarchy file permission overview make boot loader grub system volume group physical logical volume route ping single user mode rescue mode table file samba mail server web server installation apache proxy server installation squid pam plug gable authentication module performance monitor sar utility monitor sar track application causing memory leak echo variable function based tool',
#  'introduction opinionated component architecture boundary model view controller template data binding element template expression class style controller responsibility separation understanding controller boundary scope scope inheritance controller model change working inbuilt directive filter overview understanding filter expression building custom filter filter custom filter example understanding built directive understanding routing module route passing parameter route simple commerce front end page dependency injection service factory provider service service custom factory provider example service directive overview directive directive definition object compilation linking component directive example understanding server communicating angular communicating request sending header response request response transformation working get fetch data post put delete testing model jasmine unit test component protractor end end testing end end test advanced route router local storage script optimization application introduction ionic framework installation ionic ionic ionic command line sample application ionic simple ionic application mock interview mock interview mock interview mock interview',
#  'web introduction client server architecture body document event handling validation introduction asp net first web application view application model application controller type passing data view controller action selector built action filter understanding custom action filter user agent action filter example asynchronous controller razor introduction syntax working layout page partial view type view helper method binding helper binding helper model display editor helper method custom template display editor method default behaviour default model binder bind attribute introduction model data remote custom validation attribute custom validation web configuration file custom error handling cooky example understanding session login example session working session property handling global data web application entity framework operation writing business object writing generic repository repository dependency injection custom controller factory routing routing feature helper method minification web introduction simple web example client operation unit testing class unit testing controller layered architecture part layered architecture part sample small project',
#  'testing important waterfall model model agile model type requirement test strategy create efficient test strategy unit testing integration testing smoke testing system testing regression testing acceptance testing black box testing white box testing are \\ test case functional test case performance test case security test case test case defect verification defect life cycle defect test summary test report preparation testing important learn limitation manual testing limitation testing need selenium kind testing perform selenium advantage selenium difference selenium ide selenium selenium grid selenium selenium selenium ide install selenium ide recording playback selenium ide ide context menu action assertion selenium ide verify selenium ide difference assert verify selenium ide add comment selenium ide create test case save test case selenium ide test suite selenium ide import test case test suite selenium ide take selenium ide limitation selenium ide important selenium ide command open click type goback pause tool identify element object firebug locate element locate element advantage disadvantage locate element id locate element name locate element link text use selenium industry difference selenium selenium configure selenium eclipse browser selenium create script selenium form selenium find broken link application selenium alert selenium selenium selenium frame selenium give implicit explicit wait selenium capture selenium limitation selenium framework used make easy advantage install eclipse annotation running simple test script execution test hard soft assertion create file execute multiple test case create test suite advantage file perform cross browser testing generating test report poi jar file project write program read data excel sheet create property file read data property file used selenium check help section use finder tool create script integrate selenium important method used selenium configure eclipse create build execute build analyze report selenium install configure create batch file execute job basic git command working repository repository code rolling back code conflict eclipse feature selenium first program data type string class statement conditional concatenation operator loop loop practical example loop usage loop selenium object local variable global variable concept constructor concept inheritance working example interface function \\ public private default exception handling data driven framework driven framework hybrid framework difference data driven driven hybrid framework object repository selenium framework design driven framework staging',
#  'testing important waterfall model model agile model type requirement test strategy create efficient test strategy unit testing integration testing smoke testing system testing regression testing acceptance testing black box testing white box testing are \\ test case functional test case performance test case security test case test case defect verification defect life cycle defect test summary test report preparation',
#  'testing important learn limitation manual testing limitation testing need selenium kind testing perform selenium advantage selenium difference selenium ide selenium selenium grid selenium selenium selenium ide install selenium ide recording playback selenium ide ide context menu action assertion selenium ide verify selenium ide difference assert verify selenium ide add comment selenium ide create test case save test case selenium ide test suite selenium ide import test case test suite selenium ide take selenium ide limitation selenium ide important selenium ide command open click type goback pause tool identify element object firebug locate element locate element advantage disadvantage locate element id locate element name locate element link text use selenium industry difference selenium selenium configure selenium eclipse browser selenium create script selenium form selenium find broken link application selenium alert selenium selenium selenium frame selenium give implicit explicit wait selenium capture selenium limitation selenium framework used make easy advantage install eclipse annotation running simple test script execution test hard soft assertion create file execute multiple test case create test suite advantage file perform cross browser testing generating test report poi jar file project write program read data excel sheet create property file read data property file used selenium check help section use finder tool create script integrate selenium important method used selenium configure eclipse create build execute build analyze report selenium install configure create batch file execute job basic git command working repository repository code rolling back code conflict eclipse feature selenium first program data type string class statement conditional concatenation operator loop loop practical example loop usage loop selenium object local variable global variable concept constructor concept inheritance working example interface function \\ public private default exception handling data driven framework driven framework hybrid framework difference data driven driven hybrid framework object repository selenium framework design driven framework staging',
#  'getting interact dom rendering list first course project \\ —\\ monster slayer understanding instance moving “ real ” development introduction component communicating component advanced component usage second course project \\ —\\ quote handling user input form directive improving filter animation transition server via \\ —\\ resource routing application better state management final project \\ —\\ stock trader application course roundup',
#  'concept need class interface object constructor field method variable inheritance method access specifier jar file creation package printing object final variable bitwise operation operator data type generic type date calendar inner anonymous class string string buffer regular expression array switch statement exception reflection clone assertion file handling io package class type concurrency data structure collection framework concept driver socket remote communication method page cryptography encryption mail cryptographic protocol framework dependency injection spring container spring scope singleton prototype bean life cycle setup tear method destroy method spring bean definition inheritance dependency injection constructor setter method collection inner bean bean name type constructor annotation injection true false setter property constructor qualifier component life cycle spring wiring loose coupling update advice throwing around practical session model controller controller command class annotation controller hibernate transition hibernate file class annotation association persistence session transaction spring hibernate persistence entity primary key persistent field entity entity inheritance entity manager entity practical session',
#  'introduction importance asynchronous asynchronous event loop process file system module reading directory reading file streaming building server server data streaming working module package introduction routing configuration view working data working socket io process cluster child process module cluster cluster object worker object best practice node design error handling hosting node need host forever node window node window service unit testing mock interview mock interview mock interview mock interview']

# %%
df['key_words'] = clean

# %%
df.head()
# Out:
#             Courses                                    Course_Contents  \
# 0  AI & ML Training  Why we require AI and ML? Problem with traditi...
# 1  Machine Learning  Introduction to Big Data and Machine Learning ...
# 2         Angular 2  Introduction to Single page application Develo...
# 3  ReactJS Training  Introduction to ES2015 (ES6) Webpack / Babel /...
# 4        Mean Stack  Introduction to Single page application Develo...
#
#                                            key_words
# 0  require ai problem traditional system opportun...
# 1  introduction big data machine learning underst...
# 2  introduction single page application developme...
# 3  introduction project structure first react int...
# 4  introduction single page application developme...

# %% [markdown]
# # TF-IDF vectorization

# %%
# count = CountVectorizer()
tfidf = TfidfVectorizer()
count_matrix = tfidf.fit_transform(df['key_words'])

# %%
count_matrix.shape
# Out:
# (23, 998)

# %% [markdown]
# # Cosine Similarity

# %%
cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
cosine_sim
# Out:
# array([[1.        , 0.40845187, 0.0531854 , 0.0712029 , 0.0606874 ,
#         0.04759254, 0.12598425, 0.09090995, 0.05766598, 0.07146837,
#         0.07058736, 0.06324096, 0.04033862, 0.0768375 , 0.0278634 ,
#         0.07025641, 0.0606111 , 0.04249196, 0.05737721, 0.03245669,
#         0.03033289, 0.03818657, 0.05084827],
#        [0.40845187, 1.        , 0.03943243, 0.03864985, 0.04423547,
#         0.0371976 , 0.07247895, 0.07136068, 0.04609875, 0.05577112,
#         0.0369052 , 0.03439075, 0.07027103, 0.06574449, 0.02869506,
#         0.06224008, 0.04958029, 0.01876042, 0.02765832, 0.01383899,
#         0.02517811, 0.02325032, 0.07709172],
#        [0.0531854 , 0.03943243, 1.        , 0.19832677, 0.94981768,
#         0.07004002, 0.19813141, 0.2460451 , 0.08732629, 0.1017653 ,
#         0.15791367, 0.12163332, 0.0616307 , 0.09846429, 0.04961234,
#         0.3037476 , 0.17272073, 0.06113105, 0.06205329, 0.05101798,
#         0.15230791, 0.0639404 , 0.17278153],
#        [0.0712029 , 0.03864985, 0.19832677, 1.        , 0.20141381,
#         0.07740832, 0.09045702, 0.10377312, 0.08468812, 0.08056647,
#         0.06960454, 0.01372515, 0.04654942, 0.119625  , 0.02916686,
#         0.12591237, 0.09865325, 0.01656498, 0.00253259, 0.01683833,
#         0.14252661, 0.03889392, 0.10684094],
#        [0.0606874 , 0.04423547, 0.94981768, 0.20141381, 1.        ,
#         0.06976887, 0.24101037, 0.26460678, 0.09985399, 0.11335937,
#         0.17832253, 0.14448559, 0.06600418, 0.12355674, 0.07371006,
#         0.29591907, 0.19785075, 0.07395248, 0.07953278, 0.06077623,
#         0.15043143, 0.0822989 , 0.40103789],
#        [0.04759254, 0.0371976 , 0.07004002, 0.07740832, 0.06976887,
#         1.        , 0.09943858, 0.12669375, 0.8811185 , 0.14127472,
#         0.11375525, 0.03337266, 0.02315809, 0.10220562, 0.0089692 ,
#         0.12595328, 0.13875498, 0.02506435, 0.03089134, 0.01976811,
#         0.0245851 , 0.79360386, 0.08719145],
#        [0.12598425, 0.07247895, 0.19813141, 0.09045702, 0.24101037,
#         0.09943858, 1.        , 0.26449291, 0.17105526, 0.20101156,
#         0.27804266, 0.12912296, 0.05772057, 0.1154892 , 0.12631561,
#         0.11692194, 0.17489563, 0.06385729, 0.03214406, 0.06018838,
#         0.08182544, 0.14625459, 0.24964567],
#        [0.09090995, 0.07136068, 0.2460451 , 0.10377312, 0.26460678,
#         0.12669375, 0.26449291, 1.        , 0.21761561, 0.44807072,
#         0.76348116, 0.12460693, 0.49189906, 0.21041706, 0.10047656,
#         0.3465647 , 0.28685929, 0.08109628, 0.04160681, 0.07627124,
#         0.12406542, 0.20116225, 0.16176142],
#        [0.05766598, 0.04609875, 0.08732629, 0.08468812, 0.09985399,
#         0.8811185 , 0.17105526, 0.21761561, 1.        , 0.24591492,
#         0.19486324, 0.06162568, 0.05559241, 0.09484886, 0.03387176,
#         0.11930308, 0.16213419, 0.04789651, 0.0307719 , 0.04373884,
#         0.02944832, 0.92950781, 0.11473938],
#        [0.07146837, 0.05577112, 0.1017653 , 0.08056647, 0.11335937,
#         0.14127472, 0.20101156, 0.44807072, 0.24591492, 1.        ,
#         0.34556089, 0.03403784, 0.08346999, 0.15121393, 0.04138998,
#         0.1108472 , 0.1082859 , 0.06376906, 0.02728329, 0.06112154,
#         0.04564126, 0.22974125, 0.09499349],
#        [0.07058736, 0.0369052 , 0.15791367, 0.06960454, 0.17832253,
#         0.11375525, 0.27804266, 0.76348116, 0.19486324, 0.34556089,
#         1.        , 0.08941309, 0.07850934, 0.11350026, 0.10181687,
#         0.14991812, 0.17602895, 0.05669174, 0.03184195, 0.05273717,
#         0.06415675, 0.17617789, 0.14848153],
#        [0.06324096, 0.03439075, 0.12163332, 0.01372515, 0.14448559,
#         0.03337266, 0.12912296, 0.12460693, 0.06162568, 0.03403784,
#         0.08941309, 1.        , 0.0708102 , 0.01596479, 0.05205362,
#         0.06558333, 0.12981271, 0.01723954, 0.01060766, 0.01584184,
#         0.03219673, 0.06770785, 0.12972132],
#        [0.04033862, 0.07027103, 0.0616307 , 0.04654942, 0.06600418,
#         0.02315809, 0.05772057, 0.49189906, 0.05559241, 0.08346999,
#         0.07850934, 0.0708102 , 1.        , 0.16877447, 0.04750261,
#         0.10424744, 0.14995504, 0.04811877, 0.01353923, 0.04760825,
#         0.02976264, 0.05244168, 0.04157037],
#        [0.0768375 , 0.06574449, 0.09846429, 0.119625  , 0.12355674,
#         0.10220562, 0.1154892 , 0.21041706, 0.09484886, 0.15121393,
#         0.11350026, 0.01596479, 0.16877447, 1.        , 0.00213474,
#         0.1845008 , 0.06686399, 0.0305987 , 0.0095964 , 0.03006583,
#         0.04255124, 0.01329166, 0.20631233],
#        [0.0278634 , 0.02869506, 0.04961234, 0.02916686, 0.07371006,
#         0.0089692 , 0.12631561, 0.10047656, 0.03387176, 0.04138998,
#         0.10181687, 0.05205362, 0.04750261, 0.00213474, 1.        ,
#         0.04551748, 0.04941109, 0.02597256, 0.01046717, 0.02503036,
#         0.03790164, 0.03225232, 0.07156225],
#        [0.07025641, 0.06224008, 0.3037476 , 0.12591237, 0.29591907,
#         0.12595328, 0.11692194, 0.3465647 , 0.11930308, 0.1108472 ,
#         0.14991812, 0.06558333, 0.10424744, 0.1845008 , 0.04551748,
#         1.        , 0.26247448, 0.05635877, 0.10367302, 0.0372307 ,
#         0.14150011, 0.07758862, 0.13567473],
#        [0.0606111 , 0.04958029, 0.17272073, 0.09865325, 0.19785075,
#         0.13875498, 0.17489563, 0.28685929, 0.16213419, 0.1082859 ,
#         0.17602895, 0.12981271, 0.14995504, 0.06686399, 0.04941109,
#         0.26247448, 1.        , 0.05545812, 0.07256256, 0.04285083,
#         0.08572344, 0.16283555, 0.11683599],
#        [0.04249196, 0.01876042, 0.06113105, 0.01656498, 0.07395248,
#         0.02506435, 0.06385729, 0.08109628, 0.04789651, 0.06376906,
#         0.05669174, 0.01723954, 0.04811877, 0.0305987 , 0.02597256,
#         0.05635877, 0.05545812, 1.        , 0.32632001, 0.97990565,
#         0.00803864, 0.04954275, 0.03642494],
#        [0.05737721, 0.02765832, 0.06205329, 0.00253259, 0.07953278,
#         0.03089134, 0.03214406, 0.04160681, 0.0307719 , 0.02728329,
#         0.03184195, 0.01060766, 0.01353923, 0.0095964 , 0.01046717,
#         0.10367302, 0.07256256, 0.32632001, 1.        , 0.13121993,
#         0.        , 0.02846588, 0.04749918],
#        [0.03245669, 0.01383899, 0.05101798, 0.01683833, 0.06077623,
#         0.01976811, 0.06018838, 0.07627124, 0.04373884, 0.06112154,
#         0.05273717, 0.01584184, 0.04760825, 0.03006583, 0.02503036,
#         0.0372307 , 0.04285083, 0.97990565, 0.13121993, 1.        ,
#         0.00843063, 0.04595196, 0.02817822],
#        [0.03033289, 0.02517811, 0.15230791, 0.14252661, 0.15043143,
#         0.0245851 , 0.08182544, 0.12406542, 0.02944832, 0.04564126,
#         0.06415675, 0.03219673, 0.02976264, 0.04255124, 0.03790164,
#         0.14150011, 0.08572344, 0.00803864, 0.        , 0.00843063,
#         1.        , 0.02405456, 0.03087539],
#        [0.03818657, 0.02325032, 0.0639404 , 0.03889392, 0.0822989 ,
#         0.79360386, 0.14625459, 0.20116225, 0.92950781, 0.22974125,
#         0.17617789, 0.06770785, 0.05244168, 0.01329166, 0.03225232,
#         0.07758862, 0.16283555, 0.04954275, 0.02846588, 0.04595196,
#         0.02405456, 1.        , 0.05366391],
#        [0.05084827, 0.07709172, 0.17278153, 0.10684094, 0.40103789,
#         0.08719145, 0.24964567, 0.16176142, 0.11473938, 0.09499349,
#         0.14848153, 0.12972132, 0.04157037, 0.20631233, 0.07156225,
#         0.13567473, 0.11683599, 0.03642494, 0.04749918, 0.02817822,
#         0.03087539, 0.05366391, 1.        ]])

# %% [markdown]
# # Recommendation function

# %%
indices = pd.Series(df.index)

#  defining the function that takes in movie title 
# as input and returns the top 10 recommended movies
def recommendations(title, cosine_sim = cosine_sim):
    
    # initializing the empty list of recommended movies
    recommended_movies = []
    title_index = df[(df['Courses'] == title)].index[0]
    #print(title_index)
    # gettin the index of the movie that matches the title
    idx = indices[indices == title_index].index[0]

    # creating a Series with the similarity scores in descending order
    score_series = pd.Series(cosine_sim[idx]).sort_values(ascending = False)

    # getting the indexes of the 10 most similar movies
    top_10_indexes = list(score_series.iloc[1:3].index)
    
    # populating the list with the titles of the best 10 matching movies
    for i in top_10_indexes:
        recommended_movies.append(list(df.index)[i])
        
    return recommended_movies

# %% [markdown]
# # Testing

# %%
recommendations("AI & ML Training")
# Out:
# [1, 6]

# %%
r = recommendations('Software Testing')
for i in r:
    print(i, " --- ", df.iloc[i,0])
# Out:
# 19  ---  Automation
# 18  ---  Manual Testing

# %%
r = recommendations('AI & ML Training')
for i in r:
    print(i, " --- ", df.iloc[i,0])
# Out:
# 1  ---  Machine Learning
# 6  ---  Python & Django

# %%
r = recommendations('AngularJS Training')
for i in r:
    print(i, " --- ", df.iloc[i,0])
# Out:
# 7  ---  Web Development
# 2  ---  Angular 2
